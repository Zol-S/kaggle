# %% [markdown]
# # Elo Merchant Category Recommendation - LightGBM
# End date: _2019. february 19._<br/>
#
# This tutorial notebook is the second part of a seriers for [Elo Mechant Category Recommendation](https://www.kaggle.com/c/elo-merchant-category-recommendation) contest organized by Elo, one of the largest payment brands in Brazil. It has built partnerships with merchants in order to offer promotions or discounts to cardholders. The objective of the competition is to identify and serve the most relevant opportunities to individuals, by uncovering signals in customer loyalty. The input files are available from the [download](https://www.kaggle.com/c/elo-merchant-category-recommendation/data) section of the contest:
#
# - **train.csv**,  **test.csv**: list of `card_ids` that can be used for training and testing
# - **historical_transactions.csv**: contains up to 3 months' worth of transactions for every card at any of the provided `merchant_ids`
# - **new_merchant_transactions.csv**: contains the transactions at new merchants (`merchant_ids` that this particular `card_id`
# has not yet visited) over a period of two months
# - **merchants.csv**: contains aggregate information for each `merchant_id` represented in the data set

# %%
import os
import gc
import math
import random
import warnings
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import lightgbm as lgb
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error

warnings.filterwarnings("ignore")

random.seed(1)
threshold = 0.5

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Starting memory usage: {:5.2f} MB'.format(start_mem))

    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min >= np.iinfo(np.int8).min and c_max <= np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min >= np.iinfo(np.int16).min and c_max <= np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min >= np.iinfo(np.int32).min and c_max <= np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min >= np.iinfo(np.int64).min and c_max <= np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min >= np.finfo(np.float16).min and c_max <= np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min >= np.finfo(np.float32).min and c_max <= np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Reduced memory usage: {:5.2f} MB ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
def create_date_features(df, source_column, preposition):
    df[preposition + '_year'] = df[source_column].dt.year
    df[preposition + '_month'] = df[source_column].dt.month
    df[preposition + '_day'] = df[source_column].dt.day
    df[preposition + '_hour'] = df[source_column].dt.hour
    df[preposition + '_weekofyear'] = df[source_column].dt.weekofyear
    df[preposition + '_dayofweek'] = df[source_column].dt.dayofweek
    df[preposition + '_quarter'] = df[source_column].dt.quarter
    
    return df

# %% [markdown]
# ## Merchants

# %%
df_merch = pd.read_csv("input/merchants.csv", index_col="merchant_id")
print("{:,} records and {} features in merchant set.".format(df_merch.shape[0], df_merch.shape[1]))
# Out:
# 334,696 records and 21 features in merchant set.

# %%
df_merch[:3]
# Out:
#                  merchant_group_id  merchant_category_id  subsector_id  \
# merchant_id
# M_ID_838061e48c               8353                   792             9
# M_ID_9339d880ad               3184                   840            20
# M_ID_e726bbae1e                447                   690             1
#
#                  numerical_1  numerical_2 category_1 most_recent_sales_range  \
# merchant_id
# M_ID_838061e48c    -0.057471    -0.057471          N                       E
# M_ID_9339d880ad    -0.057471    -0.057471          N                       E
# M_ID_e726bbae1e    -0.057471    -0.057471          N                       E
#
#                 most_recent_purchases_range  avg_sales_lag3  \
# merchant_id
# M_ID_838061e48c                           E           -0.40
# M_ID_9339d880ad                           E           -0.72
# M_ID_e726bbae1e                           E          -82.13
#
#                  avg_purchases_lag3     ...      avg_sales_lag6  \
# merchant_id                             ...
# M_ID_838061e48c            9.666667     ...               -2.25
# M_ID_9339d880ad            1.750000     ...               -0.74
# M_ID_e726bbae1e          260.000000     ...              -82.13
#
#                  avg_purchases_lag6  active_months_lag6  avg_sales_lag12  \
# merchant_id
# M_ID_838061e48c           18.666667                   6            -2.32
# M_ID_9339d880ad            1.291667                   6            -0.57
# M_ID_e726bbae1e          260.000000                   2           -82.13
#
#                  avg_purchases_lag12  active_months_lag12  category_4 city_id  \
# merchant_id
# M_ID_838061e48c            13.916667                   12           N     242
# M_ID_9339d880ad             1.687500                   12           N      22
# M_ID_e726bbae1e           260.000000                    2           N      -1
#
#                  state_id  category_2
# merchant_id
# M_ID_838061e48c         9         1.0
# M_ID_9339d880ad        16         1.0
# M_ID_e726bbae1e         5         5.0
#
# [3 rows x 21 columns]

# %%
df_merch['category_1'] = df_merch['category_1'].map({'N': 0, 'Y': 1})
df_merch['category_2'] = pd.to_numeric(df_merch['category_2'])
df_merch['category_4'] = df_merch['category_4'].map({'N': 0, 'Y': 1})
df_merch['most_recent_sales_range'] = df_merch['most_recent_sales_range'].map({'E': 0, 'D': 1, 'C': 2, 'B': 3, 'A': 4})
df_merch['most_recent_purchases_range'] = df_merch['most_recent_purchases_range'].map({'E': 0, 'D': 1, 'C': 2, 'B': 3, 'A': 4})

# %%
df_merch[['category_1', 'category_2', 'category_4', 'most_recent_sales_range', 'most_recent_purchases_range']][:3]
# Out:
#                  category_1  category_2  category_4  most_recent_sales_range  \
# merchant_id
# M_ID_838061e48c           0         1.0           0                        0
# M_ID_9339d880ad           0         1.0           0                        0
# M_ID_e726bbae1e           0         5.0           0                        0
#
#                  most_recent_purchases_range
# merchant_id
# M_ID_838061e48c                            0
# M_ID_9339d880ad                            0
# M_ID_e726bbae1e                            0

# %%
df_merch = reduce_mem_usage(df_merch)
# Out:
# Starting memory usage: 56.18 MB
# Reduced memory usage: 21.39 MB (61.9% reduction)

# %%
df_merch = df_merch.groupby(df_merch.index).first()

# %% [markdown]
# ## Train and test data

# %%
df_train = pd.read_csv("input/train.csv")
df_train = reduce_mem_usage(df_train)

df_test = pd.read_csv("input/test.csv")
df_test = reduce_mem_usage(df_test)

print("{:,} records and {} features in train set.".format(df_train.shape[0], df_train.shape[1]))
print("{:,} records and {} features in test set.".format(df_test.shape[0], df_test.shape[1]))
# Out:
# Starting memory usage:  9.24 MB
# Reduced memory usage:  4.04 MB (56.2% reduction)
# Starting memory usage:  4.72 MB
# Reduced memory usage:  2.24 MB (52.5% reduction)
# 201,917 records and 6 features in train set.
# 123,623 records and 5 features in test set.

# %%
df_train[:3]
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557          5          2          1
# 1            2017-01  C_ID_3d0044924f          4          1          0
# 2            2016-08  C_ID_d639edf6cd          2          2          0
#
#      target
# 0 -0.820312
# 1  0.392822
# 2  0.687988

# %%
df_train["year"] = df_train["first_active_month"].str.slice(0, 4)
df_train["year"] = df_train["year"].astype(int)
df_train["month"] = df_train["first_active_month"].str.slice(5, 7)
df_train["month"] = df_train["month"].astype(int)

# %%
df_test["year"] = df_test["first_active_month"].str.slice(0, 4)
df_test["year"] = df_test[df_test['first_active_month'].isnull() == False]["year"].astype('int8')
df_test["month"] = df_test["first_active_month"].str.slice(5, 7)
df_test["month"] = df_test[df_test['first_active_month'].isnull() == False]["month"].astype('int8')

# %%
df_train[:3]
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557          5          2          1
# 1            2017-01  C_ID_3d0044924f          4          1          0
# 2            2016-08  C_ID_d639edf6cd          2          2          0
#
#      target  year  month
# 0 -0.820312  2017      6
# 1  0.392822  2017      1
# 2  0.687988  2016      8

# %%
df_test[:3]
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  year  \
# 0            2017-04  C_ID_0ab67a22ab          3          3          1 -31.0
# 1            2017-01  C_ID_130fd0cbdd          2          3          0 -31.0
# 2            2017-08  C_ID_b709037bc5          5          1          1 -31.0
#
#    month
# 0    4.0
# 1    1.0
# 2    8.0

# %% [markdown]
# ## Transactions

# %%
# %%time
df_new_trans = pd.read_csv("input/new_merchant_transactions.csv", index_col='card_id')
df_new_trans = reduce_mem_usage(df_new_trans)

# %%
# %%time
df_hist_trans = pd.read_csv("input/historical_transactions.csv", index_col='card_id')
df_hist_trans = reduce_mem_usage(df_hist_trans)

# %%
df_new_trans['authorized_flag'] = df_new_trans['authorized_flag'].map({'Y': 1, 'N': 0})
df_new_trans['category_1'] = df_new_trans['category_1'].map({'Y': 1, 'N': 0})
df_new_trans['category_3'] = df_new_trans['category_3'].map({'C': 0, 'B': 1, 'A': 2})

df_new_trans['purchase_date'] = pd.to_datetime(df_new_trans['purchase_date'])
df_new_trans = create_date_features(df_new_trans, 'purchase_date', 'purchase')

# %%
df_hist_trans['authorized_flag'] = df_hist_trans['authorized_flag'].map({'Y': 1, 'N': 0})
df_hist_trans['category_1'] = df_hist_trans['category_1'].map({'Y': 1, 'N': 0})
df_hist_trans['category_3'] = df_hist_trans['category_3'].map({'C': 0, 'B': 1, 'A': 2})

df_hist_trans['purchase_date'] = pd.to_datetime(df_hist_trans['purchase_date'])
df_hist_trans = create_date_features(df_hist_trans, 'purchase_date', 'purchase')

# %%
df_new_trans[:3]

# %%
df_hist_trans[:3]

# %% [markdown]
# ## Aggregation

# %%
def aggregate_transactions(df, prefix):  
    agg_funcs = {
        'authorized_flag': ['sum', 'mean'],

        'category_1': ['sum', 'mean'],
        'category_2': ['sum', 'mean'],
        'category_3': ['sum', 'mean'],

        'city_id': ['nunique'],
        
        'installments': ['sum', 'median', 'mean', 'max', 'min', 'std'],

        'merchant_id': ['nunique'],
        'merchant_category_id': ['nunique'],
        'month_lag': ['min', 'max', 'mean'],
        
        'state_id': ['nunique'],
        'subsector_id': ['nunique'],
        
        'purchase_amount': ['sum', 'mean', 'max', 'min', 'std'],
        'purchase_year': ['mean', 'median', 'max', 'min', 'std'],
        'purchase_month': ['mean', 'median', 'max', 'min', 'std'],
        'purchase_day': ['mean', 'median', 'max', 'min', 'std'],
        'purchase_hour': ['mean', 'median', 'max', 'min', 'std'],
        'purchase_weekofyear': ['mean', 'median', 'max', 'min', 'std'],
        'purchase_dayofweek': ['mean', 'median', 'max', 'min', 'std']

    }
    df_agg = df.groupby('card_id').agg(agg_funcs)
    df_agg.columns = [prefix + '_'.join(col).strip() for col in df_agg.columns.values]
    df_agg.reset_index(inplace=True)

    df = (df_agg.groupby('card_id').size().reset_index(name='{}transactions_count'.format(prefix)))
    df_agg = pd.merge(df, df_agg, on='card_id', how='left')

    return df_agg

# %%
df_new_trans = aggregate_transactions(df_new_trans, prefix='new_')

# %%
df_new_trans = reduce_mem_usage(df_new_trans)

# %%
df_new_trans.to_csv('input/trans_new_aggregated.csv')

# %%
df_hist_trans = aggregate_transactions(df_hist_trans, prefix='hist_')

# %%
df_hist_trans = reduce_mem_usage(df_hist_trans)

# %%
df_hist_trans.to_csv('input/trans_hist_aggregated.csv')

# %% [markdown]
# ## Merging

# %%
df_hist_trans = pd.read_csv("input/trans_hist_aggregated.csv")
df_hist_trans = reduce_mem_usage(df_hist_trans)
# Out:
# Starting memory usage: 149.02 MB
# Reduced memory usage: 36.63 MB (75.4% reduction)

# %%
df_new_trans = pd.read_csv("input/trans_new_aggregated.csv")
df_new_trans = reduce_mem_usage(df_new_trans)
# Out:
# Starting memory usage: 132.75 MB
# Reduced memory usage: 33.46 MB (74.8% reduction)

# %% [markdown]
# Join the data of the merchants and the transactions to the training and test set.

# %%
# %%time
df_train = pd.merge(df_train, df_hist_trans, on='card_id', how='left')
df_train = pd.merge(df_train, df_new_trans, on='card_id', how='left')
# Out:
# CPU times: user 1.52 s, sys: 141 ms, total: 1.66 s
# Wall time: 1.65 s

# %%
# %%time
df_test = pd.merge(df_test, df_hist_trans, on='card_id', how='left')
df_test = pd.merge(df_test, df_new_trans, on='card_id', how='left')
# Out:
# CPU times: user 1.05 s, sys: 15.6 ms, total: 1.06 s
# Wall time: 1.03 s

# %%
del df_hist_trans
del df_new_trans
gc.collect()
# Out:
# 42

# %%
df_train[:3]
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557          5          2          1
# 1            2017-01  C_ID_3d0044924f          4          1          0
# 2            2016-08  C_ID_d639edf6cd          2          2          0
#
#      target  year  month  Unnamed: 0_x  hist_transactions_count  \
# 0 -0.820312  2017      6        186538                        1
# 1  0.392822  2017      1         77733                        1
# 2  0.687988  2016      8        272262                        1
#
#               ...              new_purchase_weekofyear_mean  \
# 0             ...                                 13.304688
# 1             ...                                  9.000000
# 2             ...                                 17.000000
#
#    new_purchase_weekofyear_median  new_purchase_weekofyear_max  \
# 0                            13.0                         17.0
# 1                             9.0                         13.0
# 2                            17.0                         17.0
#
#    new_purchase_weekofyear_min  new_purchase_weekofyear_std  \
# 0                         10.0                     2.304688
# 1                          5.0                     3.687500
# 2                         17.0                          NaN
#
#    new_purchase_dayofweek_mean  new_purchase_dayofweek_median  \
# 0                     3.130859                            4.0
# 1                     1.500000                            1.0
# 2                     5.000000                            5.0
#
#    new_purchase_dayofweek_max  new_purchase_dayofweek_min  \
# 0                         6.0                         0.0
# 1                         4.0                         0.0
# 2                         5.0                         5.0
#
#    new_purchase_dayofweek_std
# 0                    2.029297
# 1                    1.643555
# 2                         NaN
#
# [3 rows x 126 columns]

# %%
df_test[:3]
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  year  \
# 0            2017-04  C_ID_0ab67a22ab          3          3          1 -31.0
# 1            2017-01  C_ID_130fd0cbdd          2          3          0 -31.0
# 2            2017-08  C_ID_b709037bc5          5          1          1 -31.0
#
#    month  Unnamed: 0_x  hist_transactions_count  hist_authorized_flag_sum  \
# 0    4.0         13622                        1                        44
# 1    1.0         24152                        1                        77
# 2    8.0        232780                        1                         9
#
#               ...              new_purchase_weekofyear_mean  \
# 0             ...                                  7.000000
# 1             ...                                 12.445312
# 2             ...                                 10.000000
#
#    new_purchase_weekofyear_median  new_purchase_weekofyear_max  \
# 0                             7.0                          9.0
# 1                            11.0                         16.0
# 2                            10.0                         11.0
#
#    new_purchase_weekofyear_min  new_purchase_weekofyear_std  \
# 0                          5.0                     2.000000
# 1                          9.0                     2.789062
# 2                          9.0                     1.414062
#
#    new_purchase_dayofweek_mean  new_purchase_dayofweek_median  \
# 0                     3.666016                            4.0
# 1                     3.000000                            4.0
# 2                     2.000000                            2.0
#
#    new_purchase_dayofweek_max  new_purchase_dayofweek_min  \
# 0                         5.0                         2.0
# 1                         6.0                         0.0
# 2                         3.0                         1.0
#
#    new_purchase_dayofweek_std
# 0                    1.527344
# 1                    2.291016
# 2                    1.414062
#
# [3 rows x 125 columns]

# %% [markdown]
# ## Training

# %% [markdown]
# ### LightGBM - all features
# For more details click [here](https://lightgbm.readthedocs.io/en/latest/).

# %%
target = df_train['target']
drops = ['card_id', 'first_active_month', 'target']
use_cols = [c for c in df_train.columns if c not in drops]
features = list(df_train[use_cols].columns)
df_train[features][:3]
# Out:
#    feature_1  feature_2  feature_3  year  month  Unnamed: 0_x  \
# 0          5          2          1  2017      6        186538
# 1          4          1          0  2017      1         77733
# 2          2          2          0  2016      8        272262
#
#    hist_transactions_count  hist_authorized_flag_sum  \
# 0                        1                       247
# 1                        1                       339
# 2                        1                        41
#
#    hist_authorized_flag_mean  hist_category_1_sum             ...              \
# 0                   0.950195                    0             ...
# 1                   0.968750                   31             ...
# 2                   0.953613                    0             ...
#
#    new_purchase_weekofyear_mean  new_purchase_weekofyear_median  \
# 0                     13.304688                            13.0
# 1                      9.000000                             9.0
# 2                     17.000000                            17.0
#
#    new_purchase_weekofyear_max  new_purchase_weekofyear_min  \
# 0                         17.0                         10.0
# 1                         13.0                          5.0
# 2                         17.0                         17.0
#
#    new_purchase_weekofyear_std  new_purchase_dayofweek_mean  \
# 0                     2.304688                     3.130859
# 1                     3.687500                     1.500000
# 2                          NaN                     5.000000
#
#    new_purchase_dayofweek_median  new_purchase_dayofweek_max  \
# 0                            4.0                         6.0
# 1                            1.0                         4.0
# 2                            5.0                         5.0
#
#    new_purchase_dayofweek_min  new_purchase_dayofweek_std
# 0                         0.0                    2.029297
# 1                         0.0                    1.643555
# 2                         5.0                         NaN
#
# [3 rows x 123 columns]

# %%
param = {
    'num_leaves': 50,
    'min_data_in_leaf': 30, 
    'objective':'regression',
    'max_depth': -1,
    'learning_rate': 0.005,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9,
    "bagging_seed": 11,
    "metric": 'rmse',
    "lambda_l1": 0.1,
    "verbosity": -1
}

folds = KFold(n_splits=5, shuffle=True, random_state=15)

oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))

feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train.values, target.values)):
    print('-')
    print("Fold {}".format(fold_ + 1))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][features], label=target.iloc[trn_idx])
    val_data = lgb.Dataset(df_train.iloc[val_idx][features], label=target.iloc[val_idx])

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds=100)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][features], num_iteration=clf.best_iteration)
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = features
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)

    predictions += clf.predict(df_test[features], num_iteration=clf.best_iteration) / folds.n_splits
# Out:
# -
# Fold 1
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.71665	valid_1's rmse: 3.79247
# [200]	training's rmse: 3.64014	valid_1's rmse: 3.75293
# [300]	training's rmse: 3.58772	valid_1's rmse: 3.73312
# [400]	training's rmse: 3.54698	valid_1's rmse: 3.72147
# [500]	training's rmse: 3.51228	valid_1's rmse: 3.7146
# [600]	training's rmse: 3.48148	valid_1's rmse: 3.71064
# [700]	training's rmse: 3.45595	valid_1's rmse: 3.70783
# [800]	training's rmse: 3.43309	valid_1's rmse: 3.70581
# [900]	training's rmse: 3.41223	valid_1's rmse: 3.7039
# [1000]	training's rmse: 3.3925	valid_1's rmse: 3.70246
# [1100]	training's rmse: 3.37435	valid_1's rmse: 3.70149
# [1200]	training's rmse: 3.35711	valid_1's rmse: 3.70111
# [1300]	training's rmse: 3.34109	valid_1's rmse: 3.7006
# [1400]	training's rmse: 3.32571	valid_1's rmse: 3.70064
# Early stopping, best iteration is:
# [1331]	training's rmse: 3.3362	valid_1's rmse: 3.70049
# -
# Fold 2
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.7333	valid_1's rmse: 3.72525
# [200]	training's rmse: 3.6557	valid_1's rmse: 3.6887
# [300]	training's rmse: 3.60222	valid_1's rmse: 3.67081
# [400]	training's rmse: 3.5622	valid_1's rmse: 3.66177
# [500]	training's rmse: 3.52721	valid_1's rmse: 3.65458
# [600]	training's rmse: 3.49664	valid_1's rmse: 3.64981
# [700]	training's rmse: 3.47076	valid_1's rmse: 3.64681
# [800]	training's rmse: 3.44807	valid_1's rmse: 3.64447
# [900]	training's rmse: 3.42705	valid_1's rmse: 3.64212
# [1000]	training's rmse: 3.40759	valid_1's rmse: 3.64028
# [1100]	training's rmse: 3.38943	valid_1's rmse: 3.63916
# [1200]	training's rmse: 3.37226	valid_1's rmse: 3.63813
# [1300]	training's rmse: 3.35623	valid_1's rmse: 3.63733
# [1400]	training's rmse: 3.341	valid_1's rmse: 3.63676
# [1500]	training's rmse: 3.32579	valid_1's rmse: 3.63626
# [1600]	training's rmse: 3.31124	valid_1's rmse: 3.63592
# [1700]	training's rmse: 3.29761	valid_1's rmse: 3.63594
# Early stopping, best iteration is:
# [1604]	training's rmse: 3.31058	valid_1's rmse: 3.63585
# -
# Fold 3
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.73853	valid_1's rmse: 3.69988
# [200]	training's rmse: 3.66009	valid_1's rmse: 3.66471
# [300]	training's rmse: 3.60675	valid_1's rmse: 3.64698
# [400]	training's rmse: 3.56658	valid_1's rmse: 3.63747
# [500]	training's rmse: 3.53245	valid_1's rmse: 3.63134
# [600]	training's rmse: 3.50165	valid_1's rmse: 3.62712
# [700]	training's rmse: 3.47597	valid_1's rmse: 3.62413
# [800]	training's rmse: 3.45328	valid_1's rmse: 3.62168
# [900]	training's rmse: 3.43243	valid_1's rmse: 3.61945
# [1000]	training's rmse: 3.41352	valid_1's rmse: 3.61781
# [1100]	training's rmse: 3.39518	valid_1's rmse: 3.61677
# [1200]	training's rmse: 3.37747	valid_1's rmse: 3.61592
# [1300]	training's rmse: 3.36122	valid_1's rmse: 3.61494
# [1400]	training's rmse: 3.34618	valid_1's rmse: 3.61408
# [1500]	training's rmse: 3.33153	valid_1's rmse: 3.61359
# [1600]	training's rmse: 3.31715	valid_1's rmse: 3.61304
# [1700]	training's rmse: 3.30318	valid_1's rmse: 3.61269
# [1800]	training's rmse: 3.28986	valid_1's rmse: 3.61224
# [1900]	training's rmse: 3.27691	valid_1's rmse: 3.61219
# [2000]	training's rmse: 3.26452	valid_1's rmse: 3.61209
# [2100]	training's rmse: 3.25253	valid_1's rmse: 3.61205
# [2200]	training's rmse: 3.24032	valid_1's rmse: 3.6118
# [2300]	training's rmse: 3.22873	valid_1's rmse: 3.61173
# Early stopping, best iteration is:
# [2224]	training's rmse: 3.23763	valid_1's rmse: 3.61171
# -
# Fold 4
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.68963	valid_1's rmse: 3.89602
# [200]	training's rmse: 3.61221	valid_1's rmse: 3.85325
# [300]	training's rmse: 3.55826	valid_1's rmse: 3.83099
# [400]	training's rmse: 3.51731	valid_1's rmse: 3.81997
# [500]	training's rmse: 3.48211	valid_1's rmse: 3.81287
# [600]	training's rmse: 3.45183	valid_1's rmse: 3.8088
# [700]	training's rmse: 3.4252	valid_1's rmse: 3.80541
# [800]	training's rmse: 3.40256	valid_1's rmse: 3.80323
# [900]	training's rmse: 3.38142	valid_1's rmse: 3.8015
# [1000]	training's rmse: 3.362	valid_1's rmse: 3.80008
# [1100]	training's rmse: 3.34324	valid_1's rmse: 3.79895
# [1200]	training's rmse: 3.32644	valid_1's rmse: 3.79832
# [1300]	training's rmse: 3.30971	valid_1's rmse: 3.79761
# [1400]	training's rmse: 3.29413	valid_1's rmse: 3.79719
# [1500]	training's rmse: 3.27946	valid_1's rmse: 3.79664
# [1600]	training's rmse: 3.26558	valid_1's rmse: 3.79656
# [1700]	training's rmse: 3.25208	valid_1's rmse: 3.79635
# [1800]	training's rmse: 3.23876	valid_1's rmse: 3.79646
# Early stopping, best iteration is:
# [1703]	training's rmse: 3.25159	valid_1's rmse: 3.79632
# -
# Fold 5
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.73399	valid_1's rmse: 3.71119
# [200]	training's rmse: 3.65596	valid_1's rmse: 3.67513
# [300]	training's rmse: 3.60275	valid_1's rmse: 3.65864
# [400]	training's rmse: 3.5622	valid_1's rmse: 3.64907
# [500]	training's rmse: 3.52691	valid_1's rmse: 3.6434
# [600]	training's rmse: 3.49687	valid_1's rmse: 3.63917
# [700]	training's rmse: 3.47079	valid_1's rmse: 3.63582
# [800]	training's rmse: 3.44774	valid_1's rmse: 3.63337
# [900]	training's rmse: 3.42663	valid_1's rmse: 3.63163
# [1000]	training's rmse: 3.40759	valid_1's rmse: 3.63036
# [1100]	training's rmse: 3.38936	valid_1's rmse: 3.62951
# [1200]	training's rmse: 3.3722	valid_1's rmse: 3.62877
# [1300]	training's rmse: 3.35596	valid_1's rmse: 3.6283
# [1400]	training's rmse: 3.34042	valid_1's rmse: 3.6276
# [1500]	training's rmse: 3.32536	valid_1's rmse: 3.62728
# [1600]	training's rmse: 3.31138	valid_1's rmse: 3.62711
# [1700]	training's rmse: 3.29773	valid_1's rmse: 3.62694
# [1800]	training's rmse: 3.28449	valid_1's rmse: 3.62674
# Early stopping, best iteration is:
# [1765]	training's rmse: 3.28899	valid_1's rmse: 3.62665

# %%
cross_validation_lgb = np.sqrt(mean_squared_error(target, oof))
print('Cross-validation score: ' + str(cross_validation_lgb))
# Out:
# Cross-validation score: 3.6748363078515935

# %%
cols = (feature_importance_df[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df['feature'].isin(cols)]

plt.figure(figsize=(14, 40))
sns.barplot(x="importance",
            y="feature",
            data=best_features.sort_values(by="importance", ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')

# %%
df_sub = pd.DataFrame({"card_id":df_test["card_id"].values})
df_sub["target"] = predictions
df_sub.to_csv("output/lgbm_{}.csv".format(cross_validation_lgb), index=False)

# %% [markdown]
# ### LightGBM - importance more than 100

# %%
list(best_features[best_features['importance'] < 100]['feature'])
# Out:
# ['feature_3',
#  'hist_transactions_count',
#  'hist_installments_median',
#  'hist_purchase_year_mean',
#  'hist_purchase_year_median',
#  'hist_purchase_year_min',
#  'hist_purchase_month_min',
#  'hist_purchase_dayofweek_max',
#  'hist_purchase_dayofweek_min',
#  'new_transactions_count',
#  'new_authorized_flag_sum',
#  'new_authorized_flag_mean',
#  'new_category_1_sum',
#  'new_category_1_mean',
#  'new_city_id_nunique',
#  'new_installments_median',
#  'new_month_lag_min',
#  'new_purchase_year_mean',
#  'new_purchase_year_median',
#  'new_purchase_year_max',
#  'new_purchase_year_min',
#  'hist_transactions_count',
#  'hist_installments_median',
#  'hist_purchase_year_mean',
#  'hist_purchase_year_median',
#  'hist_purchase_year_min',
#  'hist_purchase_dayofweek_max',
#  'hist_purchase_dayofweek_min',
#  'new_transactions_count',
#  'new_authorized_flag_sum',
#  'new_authorized_flag_mean',
#  'new_category_1_sum',
#  'new_category_1_mean',
#  'new_month_lag_min',
#  'new_purchase_year_mean',
#  'new_purchase_year_median',
#  'new_purchase_year_max',
#  'new_purchase_year_min',
#  'hist_transactions_count',
#  'hist_purchase_year_mean',
#  'hist_purchase_year_median',
#  'hist_purchase_year_min',
#  'hist_purchase_dayofweek_max',
#  'hist_purchase_dayofweek_min',
#  'new_transactions_count',
#  'new_authorized_flag_sum',
#  'new_authorized_flag_mean',
#  'new_category_1_sum',
#  'new_category_1_mean',
#  'new_month_lag_min',
#  'new_purchase_year_mean',
#  'new_purchase_year_median',
#  'new_purchase_year_max',
#  'new_purchase_year_min',
#  'hist_transactions_count',
#  'hist_installments_median',
#  'hist_purchase_year_mean',
#  'hist_purchase_year_median',
#  'hist_purchase_year_min',
#  'hist_purchase_dayofweek_max',
#  'hist_purchase_dayofweek_min',
#  'new_transactions_count',
#  'new_authorized_flag_sum',
#  'new_authorized_flag_mean',
#  'new_category_1_sum',
#  'new_category_1_mean',
#  'new_installments_median',
#  'new_month_lag_min',
#  'new_purchase_year_mean',
#  'new_purchase_year_median',
#  'new_purchase_year_max',
#  'new_purchase_year_min',
#  'hist_transactions_count',
#  'hist_installments_median',
#  'hist_purchase_year_mean',
#  'hist_purchase_year_median',
#  'hist_purchase_year_min',
#  'hist_purchase_dayofweek_max',
#  'hist_purchase_dayofweek_min',
#  'new_transactions_count',
#  'new_authorized_flag_sum',
#  'new_authorized_flag_mean',
#  'new_category_1_sum',
#  'new_category_1_mean',
#  'new_month_lag_min',
#  'new_purchase_year_mean',
#  'new_purchase_year_median',
#  'new_purchase_year_max',
#  'new_purchase_year_min']

# %%
cols = ['Unnamed: 0_x', 'feature_3', 'hist_transactions_count', 'hist_installments_median', 'hist_purchase_year_mean', 'hist_purchase_year_median', 'hist_purchase_year_min', 'hist_purchase_month_min', 'hist_purchase_dayofweek_max', 'hist_purchase_dayofweek_min', 'new_transactions_count', 'new_authorized_flag_sum', 'new_authorized_flag_mean', 'new_category_1_sum', 'new_category_1_mean', 'new_city_id_nunique', 'new_installments_median', 'new_month_lag_min', 'new_purchase_year_mean', 'new_purchase_year_median', 'new_purchase_year_max', 'new_purchase_year_min', 'hist_transactions_count', 'hist_installments_median', 'hist_purchase_year_mean', 'hist_purchase_year_median', 'hist_purchase_year_min', 'hist_purchase_dayofweek_max', 'hist_purchase_dayofweek_min', 'new_transactions_count', 'new_authorized_flag_sum', 'new_authorized_flag_mean', 'new_category_1_sum', 'new_category_1_mean', 'new_month_lag_min', 'new_purchase_year_mean', 'new_purchase_year_median', 'new_purchase_year_max', 'new_purchase_year_min', 'hist_transactions_count', 'hist_purchase_year_mean', 'hist_purchase_year_median', 'hist_purchase_year_min', 'hist_purchase_dayofweek_max', 'hist_purchase_dayofweek_min', 'new_transactions_count', 'new_authorized_flag_sum', 'new_authorized_flag_mean', 'new_category_1_sum', 'new_category_1_mean', 'new_month_lag_min', 'new_purchase_year_mean', 'new_purchase_year_median', 'new_purchase_year_max', 'new_purchase_year_min', 'hist_transactions_count', 'hist_installments_median', 'hist_purchase_year_mean', 'hist_purchase_year_median', 'hist_purchase_year_min', 'hist_purchase_dayofweek_max', 'hist_purchase_dayofweek_min', 'new_transactions_count', 'new_authorized_flag_sum', 'new_authorized_flag_mean', 'new_category_1_sum', 'new_category_1_mean', 'new_installments_median', 'new_month_lag_min', 'new_purchase_year_mean', 'new_purchase_year_median', 'new_purchase_year_max', 'new_purchase_year_min', 'hist_transactions_count', 'hist_installments_median', 'hist_purchase_year_mean', 'hist_purchase_year_median', 'hist_purchase_year_min', 'hist_purchase_dayofweek_max', 'hist_purchase_dayofweek_min', 'new_transactions_count', 'new_authorized_flag_sum', 'new_authorized_flag_mean', 'new_category_1_sum', 'new_category_1_mean', 'new_month_lag_min', 'new_purchase_year_mean', 'new_purchase_year_median', 'new_purchase_year_max', 'new_purchase_year_min']

df_train.drop(columns=cols, inplace=True, axis=1)
df_test.drop(columns=cols, inplace=True, axis=1)

# %%
drops = ['card_id', 'first_active_month', 'target']
use_cols = [c for c in df_train.columns if c not in drops]
features = list(df_train[use_cols].columns)
# Out:
#    feature_1  feature_2  year  month  hist_authorized_flag_sum  \
# 0          5          2  2017      6                       247
# 1          4          1  2017      1                       339
# 2          2          2  2016      8                        41
#
#    hist_authorized_flag_mean  hist_category_1_sum  hist_category_1_mean  \
# 0                   0.950195                    0              0.000000
# 1                   0.968750                   31              0.088562
# 2                   0.953613                    0              0.000000
#
#    hist_category_2_sum  hist_category_2_mean             ...              \
# 0                272.0              1.045898             ...
# 1                319.0              1.000000             ...
# 2                199.0              4.628906             ...
#
#    new_purchase_weekofyear_mean  new_purchase_weekofyear_median  \
# 0                     13.304688                            13.0
# 1                      9.000000                             9.0
# 2                     17.000000                            17.0
#
#    new_purchase_weekofyear_max  new_purchase_weekofyear_min  \
# 0                         17.0                         10.0
# 1                         13.0                          5.0
# 2                         17.0                         17.0
#
#    new_purchase_weekofyear_std  new_purchase_dayofweek_mean  \
# 0                     2.304688                     3.130859
# 1                     3.687500                     1.500000
# 2                          NaN                     5.000000
#
#    new_purchase_dayofweek_median  new_purchase_dayofweek_max  \
# 0                            4.0                         6.0
# 1                            1.0                         4.0
# 2                            5.0                         5.0
#
#    new_purchase_dayofweek_min  new_purchase_dayofweek_std
# 0                         0.0                    2.029297
# 1                         0.0                    1.643555
# 2                         5.0                         NaN
#
# [3 rows x 101 columns]

# %%
param = {
    'num_leaves': 50,
    'min_data_in_leaf': 30, 
    'objective':'regression',
    'max_depth': -1,
    'learning_rate': 0.005,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9,
    "bagging_seed": 11,
    "metric": 'rmse',
    "lambda_l1": 0.1,
    "verbosity": -1
}

folds = KFold(n_splits=5, shuffle=True, random_state=15)

oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))

feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train.values, target.values)):
    print('-')
    print("Fold {}".format(fold_ + 1))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][features], label=target.iloc[trn_idx])
    val_data = lgb.Dataset(df_train.iloc[val_idx][features], label=target.iloc[val_idx])

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds=100)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][features], num_iteration=clf.best_iteration)
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = features
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)

    predictions += clf.predict(df_test[features], num_iteration=clf.best_iteration) / folds.n_splits
# Out:
# -
# Fold 1
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.71697	valid_1's rmse: 3.79304
# [200]	training's rmse: 3.64031	valid_1's rmse: 3.75297
# [300]	training's rmse: 3.58774	valid_1's rmse: 3.73277
# [400]	training's rmse: 3.5472	valid_1's rmse: 3.72208
# [500]	training's rmse: 3.51293	valid_1's rmse: 3.71484
# [600]	training's rmse: 3.4824	valid_1's rmse: 3.70965
# [700]	training's rmse: 3.45613	valid_1's rmse: 3.70664
# [800]	training's rmse: 3.43397	valid_1's rmse: 3.7044
# [900]	training's rmse: 3.41278	valid_1's rmse: 3.70254
# [1000]	training's rmse: 3.39347	valid_1's rmse: 3.70121
# [1100]	training's rmse: 3.37517	valid_1's rmse: 3.70046
# [1200]	training's rmse: 3.35869	valid_1's rmse: 3.69963
# [1300]	training's rmse: 3.34272	valid_1's rmse: 3.69925
# [1400]	training's rmse: 3.32774	valid_1's rmse: 3.69884
# [1500]	training's rmse: 3.31291	valid_1's rmse: 3.69868
# [1600]	training's rmse: 3.29899	valid_1's rmse: 3.69852
# [1700]	training's rmse: 3.28489	valid_1's rmse: 3.69852
# [1800]	training's rmse: 3.27217	valid_1's rmse: 3.69846
# Early stopping, best iteration is:
# [1711]	training's rmse: 3.28338	valid_1's rmse: 3.6984
# -
# Fold 2
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.73366	valid_1's rmse: 3.72477
# [200]	training's rmse: 3.65622	valid_1's rmse: 3.68825
# [300]	training's rmse: 3.60271	valid_1's rmse: 3.66955
# [400]	training's rmse: 3.56275	valid_1's rmse: 3.66035
# [500]	training's rmse: 3.52778	valid_1's rmse: 3.65412
# [600]	training's rmse: 3.49755	valid_1's rmse: 3.64979
# [700]	training's rmse: 3.47176	valid_1's rmse: 3.64626
# [800]	training's rmse: 3.44907	valid_1's rmse: 3.64332
# [900]	training's rmse: 3.42846	valid_1's rmse: 3.64124
# [1000]	training's rmse: 3.40915	valid_1's rmse: 3.6394
# [1100]	training's rmse: 3.39074	valid_1's rmse: 3.63811
# [1200]	training's rmse: 3.37367	valid_1's rmse: 3.63683
# [1300]	training's rmse: 3.35739	valid_1's rmse: 3.63614
# [1400]	training's rmse: 3.34235	valid_1's rmse: 3.63539
# [1500]	training's rmse: 3.32732	valid_1's rmse: 3.63494
# [1600]	training's rmse: 3.31347	valid_1's rmse: 3.6346
# [1700]	training's rmse: 3.29961	valid_1's rmse: 3.63474
# Early stopping, best iteration is:
# [1633]	training's rmse: 3.30893	valid_1's rmse: 3.63444
# -
# Fold 3
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.73863	valid_1's rmse: 3.70007
# [200]	training's rmse: 3.66054	valid_1's rmse: 3.66682
# [300]	training's rmse: 3.60735	valid_1's rmse: 3.64995
# [400]	training's rmse: 3.56719	valid_1's rmse: 3.63987
# [500]	training's rmse: 3.53361	valid_1's rmse: 3.63406
# [600]	training's rmse: 3.50316	valid_1's rmse: 3.62963
# [700]	training's rmse: 3.47741	valid_1's rmse: 3.62651
# [800]	training's rmse: 3.45478	valid_1's rmse: 3.62395
# [900]	training's rmse: 3.43402	valid_1's rmse: 3.62139
# [1000]	training's rmse: 3.41468	valid_1's rmse: 3.62004
# [1100]	training's rmse: 3.39654	valid_1's rmse: 3.61908
# [1200]	training's rmse: 3.37951	valid_1's rmse: 3.61808
# [1300]	training's rmse: 3.36297	valid_1's rmse: 3.61719
# [1400]	training's rmse: 3.3474	valid_1's rmse: 3.6165
# [1500]	training's rmse: 3.33328	valid_1's rmse: 3.61617
# [1600]	training's rmse: 3.31894	valid_1's rmse: 3.61555
# [1700]	training's rmse: 3.3051	valid_1's rmse: 3.61521
# [1800]	training's rmse: 3.29199	valid_1's rmse: 3.6149
# [1900]	training's rmse: 3.27901	valid_1's rmse: 3.61475
# [2000]	training's rmse: 3.26678	valid_1's rmse: 3.61433
# [2100]	training's rmse: 3.25488	valid_1's rmse: 3.61426
# [2200]	training's rmse: 3.24228	valid_1's rmse: 3.61392
# Early stopping, best iteration is:
# [2193]	training's rmse: 3.24319	valid_1's rmse: 3.61386
# -
# Fold 4
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.69058	valid_1's rmse: 3.89613
# [200]	training's rmse: 3.61351	valid_1's rmse: 3.85313
# [300]	training's rmse: 3.55956	valid_1's rmse: 3.83059
# [400]	training's rmse: 3.51919	valid_1's rmse: 3.81989
# [500]	training's rmse: 3.48433	valid_1's rmse: 3.81292
# [600]	training's rmse: 3.45384	valid_1's rmse: 3.80835
# [700]	training's rmse: 3.42695	valid_1's rmse: 3.80525
# [800]	training's rmse: 3.40418	valid_1's rmse: 3.80309
# [900]	training's rmse: 3.38313	valid_1's rmse: 3.80144
# [1000]	training's rmse: 3.36328	valid_1's rmse: 3.8003
# [1100]	training's rmse: 3.34494	valid_1's rmse: 3.79931
# [1200]	training's rmse: 3.32777	valid_1's rmse: 3.79872
# [1300]	training's rmse: 3.31145	valid_1's rmse: 3.79835
# [1400]	training's rmse: 3.29607	valid_1's rmse: 3.79815
# [1500]	training's rmse: 3.28092	valid_1's rmse: 3.798
# Early stopping, best iteration is:
# [1486]	training's rmse: 3.28304	valid_1's rmse: 3.79792
# -
# Fold 5
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.73478	valid_1's rmse: 3.71101
# [200]	training's rmse: 3.65683	valid_1's rmse: 3.67503
# [300]	training's rmse: 3.60402	valid_1's rmse: 3.65846
# [400]	training's rmse: 3.56345	valid_1's rmse: 3.64975
# [500]	training's rmse: 3.5284	valid_1's rmse: 3.64452
# [600]	training's rmse: 3.4987	valid_1's rmse: 3.64117
# [700]	training's rmse: 3.47238	valid_1's rmse: 3.63825
# [800]	training's rmse: 3.44931	valid_1's rmse: 3.63604
# [900]	training's rmse: 3.42852	valid_1's rmse: 3.63452
# [1000]	training's rmse: 3.40964	valid_1's rmse: 3.63316
# [1100]	training's rmse: 3.39168	valid_1's rmse: 3.63231
# [1200]	training's rmse: 3.37441	valid_1's rmse: 3.63156
# [1300]	training's rmse: 3.35812	valid_1's rmse: 3.63093
# [1400]	training's rmse: 3.34258	valid_1's rmse: 3.6308
# [1500]	training's rmse: 3.32736	valid_1's rmse: 3.63063
# [1600]	training's rmse: 3.31329	valid_1's rmse: 3.6304
# [1700]	training's rmse: 3.29954	valid_1's rmse: 3.6301
# Early stopping, best iteration is:
# [1693]	training's rmse: 3.30055	valid_1's rmse: 3.63006

# %%
cross_validation_lgb = np.sqrt(mean_squared_error(target, oof))
print('Cross-validation score: ' + str(cross_validation_lgb))
# Out:
# Cross-validation score: 3.6755635261330393

# %%
cols = (feature_importance_df[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df['feature'].isin(cols)]

plt.figure(figsize=(14, 40))
sns.barplot(x="importance",
            y="feature",
            data=best_features.sort_values(by="importance", ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')

# %%
df_sub = pd.DataFrame({"card_id":df_test["card_id"].values})
df_sub["target"] = predictions
df_sub.to_csv("output/lgbm_{}.csv".format(cross_validation_lgb), index=False)

# %% [markdown]
# ### LightGBM - importance more than 100

# %%
cols = best_features[best_features['importance'] < 200]['feature']

df_train.drop(columns=cols, inplace=True, axis=1)
df_test.drop(columns=cols, inplace=True, axis=1)

# %%
drops = ['card_id', 'first_active_month', 'target']
use_cols = [c for c in df_train.columns if c not in drops]
features = list(df_train[use_cols].columns)

# %%
param = {
    'num_leaves': 50,
    'min_data_in_leaf': 30, 
    'objective':'regression',
    'max_depth': -1,
    'learning_rate': 0.005,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9,
    "bagging_seed": 11,
    "metric": 'rmse',
    "lambda_l1": 0.1,
    "verbosity": -1
}

folds = KFold(n_splits=5, shuffle=True, random_state=15)

oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))

feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train.values, target.values)):
    print('-')
    print("Fold {}".format(fold_ + 1))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][features], label=target.iloc[trn_idx])
    val_data = lgb.Dataset(df_train.iloc[val_idx][features], label=target.iloc[val_idx])

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds=100)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][features], num_iteration=clf.best_iteration)
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = features
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)

    predictions += clf.predict(df_test[features], num_iteration=clf.best_iteration) / folds.n_splits
# Out:
# -
# Fold 1
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.71728	valid_1's rmse: 3.79221
# [200]	training's rmse: 3.64113	valid_1's rmse: 3.75195
# [300]	training's rmse: 3.58919	valid_1's rmse: 3.7319
# [400]	training's rmse: 3.54925	valid_1's rmse: 3.72112
# [500]	training's rmse: 3.51522	valid_1's rmse: 3.7141
# [600]	training's rmse: 3.48513	valid_1's rmse: 3.70899
# [700]	training's rmse: 3.4595	valid_1's rmse: 3.70571
# [800]	training's rmse: 3.43736	valid_1's rmse: 3.70365
# [900]	training's rmse: 3.41681	valid_1's rmse: 3.70218
# [1000]	training's rmse: 3.39823	valid_1's rmse: 3.70109
# [1100]	training's rmse: 3.38061	valid_1's rmse: 3.70013
# [1200]	training's rmse: 3.3636	valid_1's rmse: 3.69941
# [1300]	training's rmse: 3.34769	valid_1's rmse: 3.69926
# [1400]	training's rmse: 3.33258	valid_1's rmse: 3.69915
# Early stopping, best iteration is:
# [1370]	training's rmse: 3.33697	valid_1's rmse: 3.69897
# -
# Fold 2
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.73408	valid_1's rmse: 3.72481
# [200]	training's rmse: 3.65652	valid_1's rmse: 3.68857
# [300]	training's rmse: 3.60359	valid_1's rmse: 3.67019
# [400]	training's rmse: 3.56367	valid_1's rmse: 3.6608
# [500]	training's rmse: 3.529	valid_1's rmse: 3.65425
# [600]	training's rmse: 3.49898	valid_1's rmse: 3.64946
# [700]	training's rmse: 3.47292	valid_1's rmse: 3.64616
# [800]	training's rmse: 3.45028	valid_1's rmse: 3.64332
# [900]	training's rmse: 3.42966	valid_1's rmse: 3.64089
# [1000]	training's rmse: 3.40978	valid_1's rmse: 3.63928
# [1100]	training's rmse: 3.39158	valid_1's rmse: 3.63769
# [1200]	training's rmse: 3.37481	valid_1's rmse: 3.63682
# [1300]	training's rmse: 3.35907	valid_1's rmse: 3.63608
# [1400]	training's rmse: 3.34381	valid_1's rmse: 3.63575
# [1500]	training's rmse: 3.32919	valid_1's rmse: 3.63516
# [1600]	training's rmse: 3.3149	valid_1's rmse: 3.6347
# [1700]	training's rmse: 3.30165	valid_1's rmse: 3.63459
# [1800]	training's rmse: 3.28854	valid_1's rmse: 3.63427
# [1900]	training's rmse: 3.27552	valid_1's rmse: 3.63394
# [2000]	training's rmse: 3.26238	valid_1's rmse: 3.63374
# Early stopping, best iteration is:
# [1969]	training's rmse: 3.26618	valid_1's rmse: 3.63357
# -
# Fold 3
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.73853	valid_1's rmse: 3.69977
# [200]	training's rmse: 3.66075	valid_1's rmse: 3.66564
# [300]	training's rmse: 3.6083	valid_1's rmse: 3.64849
# [400]	training's rmse: 3.56851	valid_1's rmse: 3.63854
# [500]	training's rmse: 3.53511	valid_1's rmse: 3.63266
# [600]	training's rmse: 3.50502	valid_1's rmse: 3.62823
# [700]	training's rmse: 3.47932	valid_1's rmse: 3.625
# [800]	training's rmse: 3.45674	valid_1's rmse: 3.62248
# [900]	training's rmse: 3.43607	valid_1's rmse: 3.62014
# [1000]	training's rmse: 3.41733	valid_1's rmse: 3.61875
# [1100]	training's rmse: 3.39918	valid_1's rmse: 3.61738
# [1200]	training's rmse: 3.38241	valid_1's rmse: 3.61679
# [1300]	training's rmse: 3.36677	valid_1's rmse: 3.61579
# [1400]	training's rmse: 3.35147	valid_1's rmse: 3.61512
# [1500]	training's rmse: 3.33674	valid_1's rmse: 3.61454
# [1600]	training's rmse: 3.32302	valid_1's rmse: 3.61444
# Early stopping, best iteration is:
# [1541]	training's rmse: 3.33103	valid_1's rmse: 3.61433
# -
# Fold 4
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.69007	valid_1's rmse: 3.89622
# [200]	training's rmse: 3.61326	valid_1's rmse: 3.85398
# [300]	training's rmse: 3.55922	valid_1's rmse: 3.83256
# [400]	training's rmse: 3.51854	valid_1's rmse: 3.82203
# [500]	training's rmse: 3.48306	valid_1's rmse: 3.81497
# [600]	training's rmse: 3.45324	valid_1's rmse: 3.81003
# [700]	training's rmse: 3.4263	valid_1's rmse: 3.80728
# [800]	training's rmse: 3.40299	valid_1's rmse: 3.80537
# [900]	training's rmse: 3.382	valid_1's rmse: 3.80379
# [1000]	training's rmse: 3.36267	valid_1's rmse: 3.80242
# [1100]	training's rmse: 3.34427	valid_1's rmse: 3.80153
# [1200]	training's rmse: 3.32742	valid_1's rmse: 3.80088
# [1300]	training's rmse: 3.31104	valid_1's rmse: 3.79995
# [1400]	training's rmse: 3.29586	valid_1's rmse: 3.79931
# [1500]	training's rmse: 3.28063	valid_1's rmse: 3.79909
# [1600]	training's rmse: 3.26659	valid_1's rmse: 3.799
# [1700]	training's rmse: 3.25305	valid_1's rmse: 3.79892
# [1800]	training's rmse: 3.24018	valid_1's rmse: 3.79867
# [1900]	training's rmse: 3.22757	valid_1's rmse: 3.79869
# Early stopping, best iteration is:
# [1859]	training's rmse: 3.23226	valid_1's rmse: 3.79843
# -
# Fold 5
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.73461	valid_1's rmse: 3.70997
# [200]	training's rmse: 3.65654	valid_1's rmse: 3.67392
# [300]	training's rmse: 3.60354	valid_1's rmse: 3.65704
# [400]	training's rmse: 3.56354	valid_1's rmse: 3.64827
# [500]	training's rmse: 3.52868	valid_1's rmse: 3.64287
# [600]	training's rmse: 3.49923	valid_1's rmse: 3.63916
# [700]	training's rmse: 3.47239	valid_1's rmse: 3.63654
# [800]	training's rmse: 3.44954	valid_1's rmse: 3.63427
# [900]	training's rmse: 3.42847	valid_1's rmse: 3.63231
# [1000]	training's rmse: 3.40943	valid_1's rmse: 3.63112
# [1100]	training's rmse: 3.39135	valid_1's rmse: 3.63031
# [1200]	training's rmse: 3.37458	valid_1's rmse: 3.62971
# [1300]	training's rmse: 3.35839	valid_1's rmse: 3.6292
# [1400]	training's rmse: 3.34313	valid_1's rmse: 3.62872
# Early stopping, best iteration is:
# [1382]	training's rmse: 3.34603	valid_1's rmse: 3.62857

# %%
cross_validation_lgb = np.sqrt(mean_squared_error(target, oof))
print('Cross-validation score: ' + str(cross_validation_lgb))

# %%
cols = (feature_importance_df[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df['feature'].isin(cols)]

plt.figure(figsize=(14, 40))
sns.barplot(x="importance",
            y="feature",
            data=best_features.sort_values(by="importance", ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')

# %%
df_sub = pd.DataFrame({"card_id":df_test["card_id"].values})
df_sub["target"] = predictions
df_sub.to_csv("output/lgbm_{}.csv".format(cross_validation_lgb), index=False)
