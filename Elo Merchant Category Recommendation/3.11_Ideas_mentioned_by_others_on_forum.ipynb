# %% [markdown]
# # Elo Merchant Category Recommendation - Ideas mentioned by others
# End date: _2019. february 19._<br/>
#
# This tutorial notebook is part of a series for [Elo Mechant Category Recommendation](https://www.kaggle.com/c/elo-merchant-category-recommendation) contest organized by Elo, one of the largest payment brands in Brazil. It has built partnerships with merchants in order to offer promotions or discounts to cardholders. The objective of the competition is to identify and serve the most relevant opportunities to individuals, by uncovering signals in customer loyalty. LynxKite does not yet support some of the data preprocessing, thus they need to be done in Python. The input files are available from the [download](https://www.kaggle.com/c/elo-merchant-category-recommendation/data) section of the contest:
#
# - **train.csv**,  **test.csv**: list of `card_ids` that can be used for training and testing
# - **historical_transactions.csv**: contains up to 3 months' worth of transactions for every card at any of the provided `merchant_ids`
# - **new_merchant_transactions.csv**: contains the transactions at new merchants (`merchant_ids` that this particular `card_id`
# has not yet visited) over a period of two months
# - **merchants.csv**: contains aggregate information for each `merchant_id` represented in the data set

# %%
import os
import gc
import time
import random
import warnings
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import lightgbm as lgb
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error

warnings.filterwarnings("ignore")

random.seed(1)

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Starting memory usage: {:5.2f} MB'.format(start_mem))

    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min >= np.iinfo(np.int8).min and c_max <= np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min >= np.iinfo(np.int16).min and c_max <= np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min >= np.iinfo(np.int32).min and c_max <= np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min >= np.iinfo(np.int64).min and c_max <= np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min >= np.finfo(np.float16).min and c_max <= np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min >= np.finfo(np.float32).min and c_max <= np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Reduced memory usage: {:5.2f} MB ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
def create_date_features(df, source_column, preposition):
    df[preposition + '_year'] = df[source_column].dt.year
    df[preposition + '_month'] = df[source_column].dt.month
    df[preposition + '_day'] = df[source_column].dt.day
    df[preposition + '_hour'] = df[source_column].dt.hour
    df[preposition + '_weekofyear'] = df[source_column].dt.weekofyear
    df[preposition + '_dayofweek'] = df[source_column].dt.dayofweek
    df[preposition + '_quarter'] = df[source_column].dt.quarter
    
    return df

# %% [markdown]
# ## Minimal features
# [Feature 1/2/3](https://www.kaggle.com/c/elo-merchant-category-recommendation/discussion/78839)

# %% [markdown]
# ### Train and test data

# %%
df_train = pd.read_csv("input/train.csv", index_col="card_id")
df_train = reduce_mem_usage(df_train)

df_test = pd.read_csv("input/test.csv", index_col="card_id")
df_test = reduce_mem_usage(df_test)

print("{:,} records and {} features in train set.".format(df_train.shape[0], df_train.shape[1]))
print("{:,} records and {} features in test set.".format(df_test.shape[0], df_test.shape[1]))
# Out:
# Starting memory usage:  9.24 MB
# Reduced memory usage:  4.04 MB (56.2% reduction)
# Starting memory usage:  4.72 MB
# Reduced memory usage:  2.24 MB (52.5% reduction)
# 201,917 records and 5 features in train set.
# 123,623 records and 4 features in test set.

# %%
df_train['first_active_month'] = pd.to_datetime(df_train['first_active_month'])
df_train = create_date_features(df_train, 'first_active_month', 'fa')

# %%
df_test['first_active_month'] = pd.to_datetime(df_test['first_active_month'])
df_test = create_date_features(df_test, 'first_active_month', 'fa')

# %%
df_train[:3]
# Out:
#                 first_active_month  feature_1  feature_2  feature_3    target  \
# card_id
# C_ID_92a2005557         2017-06-01          5          2          1 -0.820312
# C_ID_3d0044924f         2017-01-01          4          1          0  0.392822
# C_ID_d639edf6cd         2016-08-01          2          2          0  0.687988
#
#                  fa_year  fa_month  fa_day  fa_hour  fa_weekofyear  \
# card_id
# C_ID_92a2005557     2017         6       1        0             22
# C_ID_3d0044924f     2017         1       1        0             52
# C_ID_d639edf6cd     2016         8       1        0             31
#
#                  fa_dayofweek  fa_quarter
# card_id
# C_ID_92a2005557             3           2
# C_ID_3d0044924f             6           1
# C_ID_d639edf6cd             0           3

# %%
df_test[:3]
# Out:
#                 first_active_month  feature_1  feature_2  feature_3  fa_year  \
# card_id
# C_ID_0ab67a22ab         2017-04-01          3          3          1   2017.0
# C_ID_130fd0cbdd         2017-01-01          2          3          0   2017.0
# C_ID_b709037bc5         2017-08-01          5          1          1   2017.0
#
#                  fa_month  fa_day  fa_hour  fa_weekofyear  fa_dayofweek  \
# card_id
# C_ID_0ab67a22ab       4.0     1.0      0.0           13.0           5.0
# C_ID_130fd0cbdd       1.0     1.0      0.0           52.0           6.0
# C_ID_b709037bc5       8.0     1.0      0.0           31.0           1.0
#
#                  fa_quarter
# card_id
# C_ID_0ab67a22ab         2.0
# C_ID_130fd0cbdd         1.0
# C_ID_b709037bc5         3.0

# %% [markdown]
# ### Transactions

# %%
df_new_trans = pd.read_csv("input/new_merchant_transactions.csv", index_col="card_id", usecols=["card_id", "purchase_amount", "category_1", "category_2", "category_3", "installments"])
print("{:,} records and {} features in new transactions set.".format(df_new_trans.shape[0], df_new_trans.shape[1]))

df_new_trans = reduce_mem_usage(df_new_trans)
# Out:
# 1,963,031 records and 5 features in new transactions set.
# Starting memory usage: 89.86 MB
# Reduced memory usage: 56.16 MB (37.5% reduction)

# %%
df_hist_trans = pd.read_csv("input/historical_transactions.csv", index_col="card_id", usecols=["card_id", "purchase_amount", "category_1", "category_2", "category_3", "installments"])
print("{:,} records and {} features in historical transactions set.".format(df_hist_trans.shape[0], df_hist_trans.shape[1]))

df_hist_trans = reduce_mem_usage(df_hist_trans)
# Out:
# 29,112,361 records and 5 features in historical transactions set.
# Starting memory usage: 1332.66 MB
# Reduced memory usage: 888.44 MB (33.3% reduction)

# %%
#df_hist_trans['authorized_flag'] = df_hist_trans['authorized_flag'].map({'N': 0, 'Y': 1})
df_hist_trans['category_1'] = df_hist_trans['category_1'].map({'N': 0, 'Y': 1})
df_hist_trans['category_2'] = pd.to_numeric(df_hist_trans['category_2'])
df_hist_trans['category_3'] = df_hist_trans['category_3'].map({'A': 0, 'B': 1, 'C': 2})

# %%
#df_new_trans['authorized_flag'] = df_new_trans['authorized_flag'].map({'N': 0, 'Y': 1})
df_new_trans['category_1'] = df_new_trans['category_1'].map({'N': 0, 'Y': 1})
df_new_trans['category_2'] = pd.to_numeric(df_new_trans['category_2'])
df_new_trans['category_3'] = df_new_trans['category_3'].map({'A': 0, 'B': 1, 'C': 2})

# %% [markdown]
# #### Aggregation

# %%
def aggregate_transactions(df, prefix):  
    agg_funcs = {
        'category_1': ['sum', 'mean'],
        'category_2': ['sum', 'mean'],
        'category_3': ['sum', 'mean'],
        
        'installments': ['sum', 'median', 'mean', 'max', 'min', 'std'],
        
        'purchase_amount': ['sum', 'mean', 'max', 'min', 'std']
    }
    df_agg = df.groupby('card_id').agg(agg_funcs)
    df_agg.columns = [prefix + '_'.join(col).strip() for col in df_agg.columns.values]
    df_agg.reset_index(inplace=True)

    df = (df_agg.groupby('card_id').size().reset_index(name='{}transactions_count'.format(prefix)))
    df_agg = pd.merge(df, df_agg, on='card_id', how='left')

    return df_agg

# %%
df_new_trans = aggregate_transactions(df_new_trans, prefix='new_')

# %%
df_hist_trans = aggregate_transactions(df_hist_trans, prefix='hist_')

# %%
df_new_trans.shape, df_hist_trans.shape
# Out:
# ((290001, 19), (325540, 19))

# %%
df_new_trans[:3]
# Out:
#            card_id  new_transactions_count  new_category_1_sum  \
# 0  C_ID_00007093c1                       1                   0
# 1  C_ID_0001238066                       1                   2
# 2  C_ID_0001506ef0                       1                   0
#
#    new_category_1_mean  new_category_2_sum  new_category_2_mean  \
# 0             0.000000                 4.0             2.000000
# 1             0.076923                35.0             1.521484
# 2             0.000000                 6.0             3.000000
#
#    new_category_3_sum  new_category_3_mean  new_installments_sum  \
# 0                 2.0                 1.00                     2
# 1                29.0                 1.16                    42
# 2                 0.0                 0.00                     0
#
#    new_installments_median  new_installments_mean  new_installments_max  \
# 0                      1.0               1.000000                     1
# 1                      1.0               1.615385                    10
# 2                      0.0               0.000000                     0
#
#    new_installments_min  new_installments_std  new_purchase_amount_sum  \
# 0                     1              0.000000                -1.328125
# 1                    -1              2.079941               -14.851562
# 2                     0              0.000000                -1.447266
#
#    new_purchase_amount_mean  new_purchase_amount_max  new_purchase_amount_min  \
# 0                 -0.664062                -0.656738                -0.671875
# 1                 -0.571289                -0.078308                -0.740723
# 2                 -0.723633                -0.715332                -0.731934
#
#    new_purchase_amount_std
# 0                 0.010704
# 1                 0.173462
# 2                 0.011742

# %%
df_hist_trans[:3]
# Out:
#            card_id  hist_transactions_count  hist_category_1_sum  \
# 0  C_ID_00007093c1                        1                   28
# 1  C_ID_0001238066                        1                    2
# 2  C_ID_0001506ef0                        1                    0
#
#    hist_category_1_mean  hist_category_2_sum  hist_category_2_mean  \
# 0              0.187919                365.0              3.015625
# 1              0.016260                195.0              1.695312
# 2              0.000000                194.0              2.939453
#
#    hist_category_3_sum  hist_category_3_mean  hist_installments_sum  \
# 0                173.0              1.161074                    192
# 1                152.0              1.266667                    198
# 2                  1.0              0.015152                      1
#
#    hist_installments_median  hist_installments_mean  hist_installments_max  \
# 0                       1.0                1.288591                      6
# 1                       1.0                1.609756                     10
# 2                       0.0                0.015152                      1
#
#    hist_installments_min  hist_installments_std  hist_purchase_amount_sum  \
# 0                      1               0.764900                -76.845039
# 1                     -1               1.485637                -72.447197
# 2                      0               0.123091                -34.601879
#
#    hist_purchase_amount_mean  hist_purchase_amount_max  \
# 0                  -0.515739                  1.507069
# 1                  -0.589002                  0.768095
# 2                  -0.524271                  1.493545
#
#    hist_purchase_amount_min  hist_purchase_amount_std
# 0                 -0.728876                  0.298141
# 1                 -0.734887                  0.190235
# 2                 -0.740491                  0.472284

# %% [markdown]
# ### Merging

# %%
# %%time
df_train = pd.merge(df_train, df_hist_trans, on='card_id', how='left')
df_train = pd.merge(df_train, df_new_trans, on='card_id', how='left')
# Out:
# CPU times: user 656 ms, sys: 46.9 ms, total: 703 ms
# Wall time: 705 ms

# %%
# %%time
df_test = pd.merge(df_test, df_hist_trans, on='card_id', how='left')
df_test = pd.merge(df_test, df_new_trans, on='card_id', how='left')
# Out:
# CPU times: user 469 ms, sys: 46.9 ms, total: 516 ms
# Wall time: 508 ms

# %%
df_train.set_index("card_id", inplace=True)
df_test.set_index("card_id", inplace=True)

# %%
del df_hist_trans
del df_new_trans
gc.collect()
# Out:
# 168

# %%
df_train[:3]
# Out:
#                 first_active_month  feature_1  feature_2  feature_3    target  \
# card_id
# C_ID_92a2005557         2017-06-01          5          2          1 -0.820312
# C_ID_3d0044924f         2017-01-01          4          1          0  0.392822
# C_ID_d639edf6cd         2016-08-01          2          2          0  0.687988
#
#                  fa_year  fa_month  fa_day  fa_hour  fa_weekofyear  \
# card_id
# C_ID_92a2005557     2017         6       1        0             22
# C_ID_3d0044924f     2017         1       1        0             52
# C_ID_d639edf6cd     2016         8       1        0             31
#
#                           ...             new_installments_median  \
# card_id                   ...
# C_ID_92a2005557           ...                                 0.0
# C_ID_3d0044924f           ...                                 1.0
# C_ID_d639edf6cd           ...                                 0.0
#
#                  new_installments_mean  new_installments_max  \
# card_id
# C_ID_92a2005557                    0.0                   0.0
# C_ID_3d0044924f                    1.0                   1.0
# C_ID_d639edf6cd                    0.0                   0.0
#
#                  new_installments_min  new_installments_std  \
# card_id
# C_ID_92a2005557                   0.0                   0.0
# C_ID_3d0044924f                   1.0                   0.0
# C_ID_d639edf6cd                   0.0                   NaN
#
#                  new_purchase_amount_sum  new_purchase_amount_mean  \
# card_id
# C_ID_92a2005557               -13.242188                 -0.575684
# C_ID_3d0044924f                -4.355469                 -0.726074
# C_ID_d639edf6cd                -0.700195                 -0.700195
#
#                  new_purchase_amount_max  new_purchase_amount_min  \
# card_id
# C_ID_92a2005557                -0.296143                -0.724609
# C_ID_3d0044924f                -0.701660                -0.739258
# C_ID_d639edf6cd                -0.700195                -0.700195
#
#                  new_purchase_amount_std
# card_id
# C_ID_92a2005557                 0.135742
# C_ID_3d0044924f                 0.014381
# C_ID_d639edf6cd                      NaN
#
# [3 rows x 48 columns]

# %%
df_test[:3]
# Out:
#                 first_active_month  feature_1  feature_2  feature_3  fa_year  \
# card_id
# C_ID_0ab67a22ab         2017-04-01          3          3          1   2017.0
# C_ID_130fd0cbdd         2017-01-01          2          3          0   2017.0
# C_ID_b709037bc5         2017-08-01          5          1          1   2017.0
#
#                  fa_month  fa_day  fa_hour  fa_weekofyear  fa_dayofweek  \
# card_id
# C_ID_0ab67a22ab       4.0     1.0      0.0           13.0           5.0
# C_ID_130fd0cbdd       1.0     1.0      0.0           52.0           6.0
# C_ID_b709037bc5       8.0     1.0      0.0           31.0           1.0
#
#                           ...             new_installments_median  \
# card_id                   ...
# C_ID_0ab67a22ab           ...                                 1.0
# C_ID_130fd0cbdd           ...                                 1.0
# C_ID_b709037bc5           ...                                 5.5
#
#                  new_installments_mean  new_installments_max  \
# card_id
# C_ID_0ab67a22ab               1.666667                   3.0
# C_ID_130fd0cbdd               1.222222                   3.0
# C_ID_b709037bc5               5.500000                  10.0
#
#                  new_installments_min  new_installments_std  \
# card_id
# C_ID_0ab67a22ab                   1.0              1.154701
# C_ID_130fd0cbdd                   1.0              0.666667
# C_ID_b709037bc5                   1.0              6.363961
#
#                  new_purchase_amount_sum  new_purchase_amount_mean  \
# card_id
# C_ID_0ab67a22ab                -1.777344                 -0.592285
# C_ID_130fd0cbdd                -5.945312                 -0.660645
# C_ID_b709037bc5                 0.179688                  0.089844
#
#                  new_purchase_amount_max  new_purchase_amount_min  \
# card_id
# C_ID_0ab67a22ab                -0.383301                -0.722168
# C_ID_130fd0cbdd                -0.506348                -0.740723
# C_ID_b709037bc5                 0.904297                -0.724609
#
#                  new_purchase_amount_std
# card_id
# C_ID_0ab67a22ab                 0.182861
# C_ID_130fd0cbdd                 0.071167
# C_ID_b709037bc5                 1.152344
#
# [3 rows x 47 columns]

# %% [markdown]
# ### Training

# %%
target = df_train['target']
features = [c for c in df_train.columns if c not in ['first_active_month', 'target']]

# %%
param = {
    "bagging_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_seed": 11,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "lambda_l1": 0.1,
    'learning_rate': 0.005,
    'max_depth': -1,
    "metric": 'rmse',
    "min_child_weight": 0.01,
    'min_data_in_leaf': 30, 
    'num_leaves': 50,
    'objective':'regression',
    "seed": 1,
    "verbosity": -1
}

folds = KFold(n_splits=5, shuffle=True, random_state=15)

oof = np.zeros(len(df_train[features]))
predictions = np.zeros(len(df_test))

feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train.values, target.values)):
    print("\nFold {}.".format(fold_ + 1))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][features], label=target.iloc[trn_idx])
    val_data = lgb.Dataset(df_train.iloc[val_idx][features], label=target.iloc[val_idx])

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds=100)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][features], num_iteration=clf.best_iteration)
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = features
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)

    predictions += clf.predict(df_test[features], num_iteration=clf.best_iteration) / folds.n_splits
# Out:
# Fold 1.
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.79701	valid_1's rmse: 3.85389
# [200]	training's rmse: 3.76701	valid_1's rmse: 3.83915
# [300]	training's rmse: 3.74359	valid_1's rmse: 3.83148
# [400]	training's rmse: 3.72386	valid_1's rmse: 3.82657
# [500]	training's rmse: 3.70615	valid_1's rmse: 3.82362
# [600]	training's rmse: 3.69028	valid_1's rmse: 3.82154
# [700]	training's rmse: 3.67603	valid_1's rmse: 3.82016
# [800]	training's rmse: 3.66285	valid_1's rmse: 3.81924
# [900]	training's rmse: 3.6509	valid_1's rmse: 3.81864
# [1000]	training's rmse: 3.63957	valid_1's rmse: 3.81833
# [1100]	training's rmse: 3.62905	valid_1's rmse: 3.81802
# [1200]	training's rmse: 3.6192	valid_1's rmse: 3.81783
# [1300]	training's rmse: 3.60965	valid_1's rmse: 3.81769
# [1400]	training's rmse: 3.60023	valid_1's rmse: 3.81762
# [1500]	training's rmse: 3.59126	valid_1's rmse: 3.81774
# Early stopping, best iteration is:
# [1428]	training's rmse: 3.59772	valid_1's rmse: 3.8176
#
# Fold 2.
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.81533	valid_1's rmse: 3.77807
# [200]	training's rmse: 3.78479	valid_1's rmse: 3.76467
# [300]	training's rmse: 3.76046	valid_1's rmse: 3.7574
# [400]	training's rmse: 3.74066	valid_1's rmse: 3.75309
# [500]	training's rmse: 3.7231	valid_1's rmse: 3.75034
# [600]	training's rmse: 3.70759	valid_1's rmse: 3.74837
# [700]	training's rmse: 3.69344	valid_1's rmse: 3.74712
# [800]	training's rmse: 3.68065	valid_1's rmse: 3.74648
# [900]	training's rmse: 3.66877	valid_1's rmse: 3.74599
# [1000]	training's rmse: 3.65717	valid_1's rmse: 3.74558
# [1100]	training's rmse: 3.64631	valid_1's rmse: 3.74553
# Early stopping, best iteration is:
# [1068]	training's rmse: 3.64971	valid_1's rmse: 3.74542
#
# Fold 3.
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.82187	valid_1's rmse: 3.75085
# [200]	training's rmse: 3.79146	valid_1's rmse: 3.73702
# [300]	training's rmse: 3.76777	valid_1's rmse: 3.72873
# [400]	training's rmse: 3.74764	valid_1's rmse: 3.72383
# [500]	training's rmse: 3.73005	valid_1's rmse: 3.72088
# [600]	training's rmse: 3.71449	valid_1's rmse: 3.719
# [700]	training's rmse: 3.69997	valid_1's rmse: 3.71777
# [800]	training's rmse: 3.68663	valid_1's rmse: 3.71678
# [900]	training's rmse: 3.67417	valid_1's rmse: 3.71618
# [1000]	training's rmse: 3.66263	valid_1's rmse: 3.71591
# [1100]	training's rmse: 3.65183	valid_1's rmse: 3.7157
# [1200]	training's rmse: 3.64151	valid_1's rmse: 3.71547
# [1300]	training's rmse: 3.63165	valid_1's rmse: 3.71566
# Early stopping, best iteration is:
# [1200]	training's rmse: 3.64151	valid_1's rmse: 3.71547
#
# Fold 4.
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.76851	valid_1's rmse: 3.9612
# [200]	training's rmse: 3.73666	valid_1's rmse: 3.94961
# [300]	training's rmse: 3.71184	valid_1's rmse: 3.94348
# [400]	training's rmse: 3.69153	valid_1's rmse: 3.93987
# [500]	training's rmse: 3.67312	valid_1's rmse: 3.93768
# [600]	training's rmse: 3.65686	valid_1's rmse: 3.93657
# [700]	training's rmse: 3.64245	valid_1's rmse: 3.93587
# [800]	training's rmse: 3.62918	valid_1's rmse: 3.93533
# [900]	training's rmse: 3.61708	valid_1's rmse: 3.93514
# [1000]	training's rmse: 3.60567	valid_1's rmse: 3.93513
# [1100]	training's rmse: 3.59479	valid_1's rmse: 3.93489
# [1200]	training's rmse: 3.58487	valid_1's rmse: 3.93477
# Early stopping, best iteration is:
# [1198]	training's rmse: 3.58508	valid_1's rmse: 3.93474
#
# Fold 5.
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.81819	valid_1's rmse: 3.76685
# [200]	training's rmse: 3.78689	valid_1's rmse: 3.75393
# [300]	training's rmse: 3.76297	valid_1's rmse: 3.74732
# [400]	training's rmse: 3.74254	valid_1's rmse: 3.74337
# [500]	training's rmse: 3.72504	valid_1's rmse: 3.74093
# [600]	training's rmse: 3.70899	valid_1's rmse: 3.73937
# [700]	training's rmse: 3.69461	valid_1's rmse: 3.7382
# [800]	training's rmse: 3.68134	valid_1's rmse: 3.73766
# [900]	training's rmse: 3.66895	valid_1's rmse: 3.73708
# [1000]	training's rmse: 3.65772	valid_1's rmse: 3.73685
# [1100]	training's rmse: 3.647	valid_1's rmse: 3.73684
# Early stopping, best iteration is:
# [1069]	training's rmse: 3.65024	valid_1's rmse: 3.73674

# %%
cross_validation_lgb = np.sqrt(mean_squared_error(target, oof))
print('Cross-validation score: ' + str(cross_validation_lgb))
# Out:
# Cross-validation score: 3.790841675672712

# %%
cols = (feature_importance_df[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df['feature'].isin(cols)]

plt.figure(figsize=(14, 40))
sns.barplot(x="importance",
            y="feature",
            data=best_features.sort_values(by="importance", ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')

# %%
clf.save_model('models/regression_konstantin_yakovlev.txt')

# %%
df_sub = pd.DataFrame({
    "card_id": df_test.index
})

df_sub["target"] = predictions
df_sub.to_csv("output/regression_{}.csv".format(cross_validation_lgb), index=False)

# %% [markdown]
# ## Play-Kaggle
# [Feature engineering](https://github.com/zzsza/Play-Kaggle/blob/master/Elo-Merchant-Category-Recommendation/notebooks/03.Feature-Engineering.ipynb)

# %%
# %%time
new_transactions = pd.read_csv('input/new_merchant_transactions.csv', parse_dates=['purchase_date'])
historical_transactions = pd.read_csv('input/historical_transactions.csv', parse_dates=['purchase_date'])

def binarize(df):
    for col in ['authorized_flag', 'category_1']:
        df[col] = df[col].map({'Y':1, 'N':0})
    return df

historical_transactions = binarize(historical_transactions)
new_transactions = binarize(new_transactions)
# Out:
# CPU times: user 1min 22s, sys: 46.9 s, total: 2min 9s
# Wall time: 2min 29s

# %%
# %%time
def read_data(input_file):
    df = pd.read_csv(input_file)
    df['first_active_month'] = pd.to_datetime(df['first_active_month'])
    df['elapsed_time'] = (datetime.date(2018, 2, 1) - df['first_active_month'].dt.date).dt.days
    return df

train = read_data('input/train.csv')
test = read_data('input/test.csv')

target = train['target']
del train['target']
# Out:
# CPU times: user 1.77 s, sys: 46.9 ms, total: 1.81 s
# Wall time: 1.91 s

# %% [markdown]
# ### Feature engineering

# %%
historical_transactions['month_diff'] = ((datetime.datetime.today() - historical_transactions['purchase_date']).dt.days)//30

# %%
historical_transactions['month_diff'] += historical_transactions['month_lag']

# %%
new_transactions['month_diff'] = ((datetime.datetime.today() - new_transactions['purchase_date']).dt.days)//30
new_transactions['month_diff'] += new_transactions['month_lag']

# %%
historical_transactions = pd.get_dummies(historical_transactions, columns=['category_2', 'category_3'])
new_transactions = pd.get_dummies(new_transactions, columns=['category_2', 'category_3'])

historical_transactions = reduce_mem_usage(historical_transactions)
new_transactions = reduce_mem_usage(new_transactions)
# Out:
# Starting memory usage: 3109.54 MB
# Reduced memory usage: 1332.66 MB (57.1% reduction)
# Starting memory usage: 209.67 MB
# Reduced memory usage: 86.12 MB (58.9% reduction)

# %%
agg_fun = {'authorized_flag': ['mean']}

# %%
auth_mean = historical_transactions.groupby(['card_id']).agg(agg_fun)

# %%
auth_mean.columns = ['_'.join(col).strip() for col in auth_mean.columns.values]

# %%
auth_mean.reset_index(inplace=True)

authorized_transactions = historical_transactions[historical_transactions['authorized_flag'] == 1]
historical_transactions = historical_transactions[historical_transactions['authorized_flag'] == 0]

# %%
historical_transactions['purchase_month'] = historical_transactions['purchase_date'].dt.month
authorized_transactions['purchase_month'] = authorized_transactions['purchase_date'].dt.month
new_transactions['purchase_month'] = new_transactions['purchase_date'].dt.month

# %%
# %%time
def aggregate_transactions(history):
    
    history.loc[:, 'purchase_date'] = pd.DatetimeIndex(history['purchase_date']).\
                                      astype(np.int64) * 1e-9
    
    agg_func = {
    'category_1': ['sum', 'mean'],
    'category_2_1.0': ['mean'],
    'category_2_2.0': ['mean'],
    'category_2_3.0': ['mean'],
    'category_2_4.0': ['mean'],
    'category_2_5.0': ['mean'],
    'category_3_A': ['mean'],
    'category_3_B': ['mean'],
    'category_3_C': ['mean'],
    'merchant_id': ['nunique'],
    'merchant_category_id': ['nunique'],
    'state_id': ['nunique'],
    'city_id': ['nunique'],
    'subsector_id': ['nunique'],
    'purchase_amount': ['sum', 'mean', 'max', 'min', 'std'],
    'installments': ['sum', 'mean', 'max', 'min', 'std'],
    'purchase_month': ['mean', 'max', 'min', 'std'],
    'purchase_date': [np.ptp, 'min', 'max'],
    'month_lag': ['mean', 'max', 'min', 'std'],
    'month_diff': ['mean']
    }
    
    agg_history = history.groupby(['card_id']).agg(agg_func)
    agg_history.columns = ['_'.join(col).strip() for col in agg_history.columns.values]
    agg_history.reset_index(inplace=True)
    
    df = (history.groupby('card_id')
          .size()
          .reset_index(name='transactions_count'))
    
    agg_history = pd.merge(df, agg_history, on='card_id', how='left')
    
    return agg_history
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 15.3 µs

# %%
# %%time
history = aggregate_transactions(historical_transactions)
history.columns = ['hist_' + c if c != 'card_id' else c for c in history.columns]
# Out:
# CPU times: user 46.9 s, sys: 188 ms, total: 47.1 s
# Wall time: 47.9 s

# %%
history[:5]
# Out:
#            card_id  hist_transactions_count  hist_category_1_sum  \
# 0  C_ID_00007093c1                       35                  4.0
# 1  C_ID_0001238066                        3                  0.0
# 2  C_ID_0001506ef0                        4                  0.0
# 3  C_ID_0001793786                       27                  2.0
# 4  C_ID_000183fdda                        7                  0.0
#
#    hist_category_1_mean  hist_category_2_1.0_mean  hist_category_2_2.0_mean  \
# 0              0.114286                  0.000000                  0.000000
# 1              0.000000                  0.333333                  0.000000
# 2              0.000000                  0.000000                  0.000000
# 3              0.074074                  0.111111                  0.296296
# 4              0.000000                  0.000000                  0.000000
#
#    hist_category_2_3.0_mean  hist_category_2_4.0_mean  \
# 0                  0.885714                       0.0
# 1                  0.000000                       0.0
# 2                  1.000000                       0.0
# 3                  0.111111                       0.0
# 4                  1.000000                       0.0
#
#    hist_category_2_5.0_mean  hist_category_3_A_mean          ...           \
# 0                  0.000000                0.000000          ...
# 1                  0.666667                0.000000          ...
# 2                  0.000000                0.750000          ...
# 3                  0.000000                0.814815          ...
# 4                  0.000000                0.000000          ...
#
#    hist_purchase_month_min  hist_purchase_month_std  hist_purchase_date_ptp  \
# 0                        1                 3.071419              28858113.0
# 1                        2                 5.773503               3609150.0
# 2                        2                 4.725816              22098875.0
# 3                        3                 2.375684              16780236.0
# 4                        8                 0.755929               6701589.0
#
#    hist_purchase_date_min  hist_purchase_date_max  hist_month_lag_mean  \
# 0            1.489250e+09            1.518108e+09            -6.028571
# 1            1.514660e+09            1.518269e+09            -1.333333
# 2            1.496772e+09            1.518871e+09            -2.500000
# 3            1.488636e+09            1.505416e+09            -3.518519
# 4            1.502099e+09            1.508801e+09            -5.714286
#
#    hist_month_lag_max  hist_month_lag_min  hist_month_lag_std  \
# 0                   0                 -11            3.535415
# 1                   0                  -2            1.154701
# 2                   0                  -8            3.785939
# 3                  -1                  -7            2.375684
# 4                  -4                  -6            0.755929
#
#    hist_month_diff_mean
# 0             11.800000
# 1             11.333333
# 2             11.750000
# 3             15.740741
# 4             11.285714
#
# [5 rows x 39 columns]

# %%
authorized = aggregate_transactions(authorized_transactions)
authorized.columns = ['auth_' + c if c != 'card_id' else c for c in authorized.columns]

# %%
authorized[:5]
# Out:
#            card_id  auth_transactions_count  auth_category_1_sum  \
# 0  C_ID_00007093c1                      114                 24.0
# 1  C_ID_0001238066                      120                  2.0
# 2  C_ID_0001506ef0                       62                  0.0
# 3  C_ID_0001793786                      189                  0.0
# 4  C_ID_000183fdda                      137                  4.0
#
#    auth_category_1_mean  auth_category_2_1.0_mean  auth_category_2_2.0_mean  \
# 0              0.210526                  0.000000                  0.000000
# 1              0.016667                  0.783333                  0.000000
# 2              0.000000                  0.032258                  0.000000
# 3              0.000000                  0.042328                  0.359788
# 4              0.029197                  0.051095                  0.007299
#
#    auth_category_2_3.0_mean  auth_category_2_4.0_mean  \
# 0                  0.780702                       0.0
# 1                  0.000000                       0.0
# 2                  0.967742                       0.0
# 3                  0.063492                       0.0
# 4                  0.905109                       0.0
#
#    auth_category_2_5.0_mean  auth_category_3_A_mean          ...           \
# 0                  0.008772                     0.0          ...
# 1                  0.150000                     0.0          ...
# 2                  0.000000                     1.0          ...
# 3                  0.000000                     1.0          ...
# 4                  0.007299                     0.0          ...
#
#    auth_purchase_month_min  auth_purchase_month_std  auth_purchase_date_ptp  \
# 0                        1                 3.371490              32627654.0
# 1                        1                 4.895483              13110825.0
# 2                        1                 4.538017              34460275.0
# 3                        1                 2.301491              24487497.0
# 4                        1                 4.538289              15148616.0
#
#    auth_purchase_date_min  auth_purchase_date_max  auth_month_lag_mean  \
# 0            1.487081e+09            1.519708e+09            -5.798246
# 1            1.506638e+09            1.519748e+09            -1.825000
# 2            1.484411e+09            1.518871e+09            -4.983871
# 3            1.484994e+09            1.509481e+09            -3.301587
# 4            1.504444e+09            1.519592e+09            -2.284672
#
#    auth_month_lag_max  auth_month_lag_min  auth_month_lag_std  \
# 0                   0                 -12            3.441495
# 1                   0                  -5            1.294218
# 2                   0                 -13            4.248402
# 3                   0                  -9            2.301491
# 4                   0                  -5            1.782055
#
#    auth_month_diff_mean
# 0             11.771930
# 1             11.483333
# 2             11.822581
# 3             15.661376
# 4             11.635036
#
# [5 rows x 39 columns]

# %%
new = aggregate_transactions(new_transactions)
new.columns = ['new_' + c if c != 'card_id' else c for c in new.columns]

# %%
new[:5]
# Out:
#            card_id  new_transactions_count  new_category_1_sum  \
# 0  C_ID_00007093c1                       2                   0
# 1  C_ID_0001238066                      26                   2
# 2  C_ID_0001506ef0                       2                   0
# 3  C_ID_0001793786                      31                   0
# 4  C_ID_000183fdda                      11                   0
#
#    new_category_1_mean  new_category_2_1.0_mean  new_category_2_2.0_mean  \
# 0             0.000000                 0.500000                 0.000000
# 1             0.076923                 0.769231                 0.000000
# 2             0.000000                 0.000000                 0.000000
# 3             0.000000                 0.483871                 0.258065
# 4             0.000000                 0.000000                 0.000000
#
#    new_category_2_3.0_mean  new_category_2_4.0_mean  new_category_2_5.0_mean  \
# 0                  0.50000                      0.0                 0.000000
# 1                  0.00000                      0.0                 0.115385
# 2                  1.00000                      0.0                 0.000000
# 3                  0.16129                      0.0                 0.032258
# 4                  1.00000                      0.0                 0.000000
#
#    new_category_3_A_mean         ...           new_purchase_month_min  \
# 0                    0.0         ...                                4
# 1                    0.0         ...                                3
# 2                    1.0         ...                                3
# 3                    1.0         ...                               11
# 4                    0.0         ...                                3
#
#    new_purchase_month_std  new_purchase_date_ptp  new_purchase_date_min  \
# 0                0.000000               537024.0           1.522754e+09
# 1                0.485165              5195343.0           1.519923e+09
# 2                0.000000               471152.0           1.521239e+09
# 3                0.475191              3981096.0           1.510761e+09
# 4                0.467099              5106807.0           1.519994e+09
#
#    new_purchase_date_max  new_month_lag_mean  new_month_lag_max  \
# 0           1.523291e+09            2.000000                  2
# 1           1.525118e+09            1.346154                  2
# 2           1.521710e+09            1.000000                  1
# 3           1.514742e+09            1.322581                  2
# 4           1.525100e+09            1.272727                  2
#
#    new_month_lag_min  new_month_lag_std  new_month_diff_mean
# 0                  2           0.000000            12.000000
# 1                  1           0.485165            11.461538
# 2                  1           0.000000            11.500000
# 3                  1           0.475191            15.290323
# 4                  1           0.467099            11.727273
#
# [5 rows x 39 columns]

# %%
def aggregate_per_month(history):
    grouped = history.groupby(['card_id', 'month_lag'])

    agg_func = {
            'purchase_amount': ['count', 'sum', 'mean', 'min', 'max', 'std'],
            'installments': ['count', 'sum', 'mean', 'min', 'max', 'std'],
            }

    intermediate_group = grouped.agg(agg_func)
    intermediate_group.columns = ['_'.join(col).strip() for col in intermediate_group.columns.values]
    intermediate_group.reset_index(inplace=True)

    final_group = intermediate_group.groupby('card_id').agg(['mean', 'std'])
    final_group.columns = ['_'.join(col).strip() for col in final_group.columns.values]
    final_group.reset_index(inplace=True)
    
    return final_group
#___________________________________________________________
final_group =  aggregate_per_month(authorized_transactions) 
final_group[:10]
# Out:
#            card_id  month_lag_mean  month_lag_std  purchase_amount_count_mean  \
# 0  C_ID_00007093c1       -6.000000       3.894440                    8.769231
# 1  C_ID_0001238066       -2.500000       1.870829                   20.000000
# 2  C_ID_0001506ef0       -6.230769       4.225988                    4.769231
# 3  C_ID_0001793786       -4.500000       3.027650                   18.900000
# 4  C_ID_000183fdda       -2.500000       1.870829                   22.833333
# 5  C_ID_00024e244b       -6.384615       4.330867                    4.076923
# 6  C_ID_0002709b5a       -5.000000       3.316625                    6.090909
# 7  C_ID_00027503e2       -4.000000       2.738613                    2.666667
# 8  C_ID_000298032a       -5.250000       4.334249                    3.500000
# 9  C_ID_0002ba3c2e       -4.666667       3.141125                    9.166667
#
#    purchase_amount_count_std  purchase_amount_sum_mean  \
# 0                   3.539158                 -4.803313
# 1                  11.696153                -11.776212
# 2                   4.342692                 -2.438161
# 3                  12.160501                 -2.496067
# 4                   7.167054                -11.316092
# 5                   4.290717                 -2.557395
# 6                   3.505839                 -3.994622
# 7                   1.224745                 -1.974976
# 8                   1.772811                 -1.844563
# 9                   4.665476                 -5.843051
#
#    purchase_amount_sum_std  purchase_amount_mean_mean  \
# 0                 2.175011                  -0.536131
# 1                 6.676914                  -0.603215
# 2                 2.902502                  -0.446660
# 3                 4.018810                  -0.005687
# 4                 4.800612                  -0.489227
# 5                 2.089708                  -0.685118
# 6                 2.440540                  -0.638637
# 7                 0.909524                  -0.740077
# 8                 0.699127                  -0.590214
# 9                 3.021165                  -0.638037
#
#    purchase_amount_mean_std  purchase_amount_min_mean          ...           \
# 0                  0.075418                 -0.702649          ...
# 1                  0.046045                 -0.730351          ...
# 2                  0.271125                 -0.725724          ...
# 3                  0.271221                 -0.646277          ...
# 4                  0.141015                 -0.728405          ...
# 5                  0.071894                 -0.728885          ...
# 6                  0.060836                 -0.700104          ...
# 7                  0.002424                 -0.742206          ...
# 8                  0.168008                 -0.686623          ...
# 9                  0.044976                 -0.721448          ...
#
#    installments_sum_mean  installments_sum_std  installments_mean_mean  \
# 0              11.307692              4.210792                1.369646
# 1              32.500000             24.501020                1.652873
# 2               0.000000              0.000000                0.000000
# 3               0.000000              0.000000                0.000000
# 4              40.833333             14.048725                1.834943
# 5               0.000000              0.000000                0.000000
# 6              10.727273              8.427229                1.965729
# 7               0.000000              0.000000                0.000000
# 8               0.000000              0.000000                0.000000
# 9               0.000000              0.000000                0.000000
#
#    installments_mean_std  installments_min_mean  installments_min_std  \
# 0               0.423190               1.000000              0.000000
# 1               0.410539               0.666667              0.816497
# 2               0.000000               0.000000              0.000000
# 3               0.000000               0.000000              0.000000
# 4               0.362557               0.333333              1.032796
# 5               0.000000               0.000000              0.000000
# 6               1.287108               0.818182              0.603023
# 7               0.000000               0.000000              0.000000
# 8               0.000000               0.000000              0.000000
# 9               0.000000               0.000000              0.000000
#
#    installments_max_mean  installments_max_std  installments_std_mean  \
# 0               2.538462              1.613246               0.625428
# 1               4.666667              2.875181               1.256525
# 2               0.000000              0.000000               0.000000
# 3               0.000000              0.000000               0.000000
# 4               9.166667              2.041241               2.144389
# 5               0.000000              0.000000               0.000000
# 6               3.818182              3.341203               1.600058
# 7               0.000000              0.000000               0.000000
# 8               0.000000              0.000000               0.000000
# 9               0.000000              0.000000               0.000000
#
#    installments_std_std
# 0              0.675607
# 1              0.521292
# 2              0.000000
# 3              0.000000
# 4              0.665529
# 5              0.000000
# 6              1.734256
# 7              0.000000
# 8              0.000000
# 9              0.000000
#
# [10 rows x 27 columns]

# %%
def successive_aggregates(df, field1, field2):
    t = df.groupby(['card_id', field1])[field2].mean()
    u = pd.DataFrame(t).reset_index().groupby('card_id')[field2].agg(['mean', 'min', 'max', 'std'])
    u.columns = [field1 + '_' + field2 + '_' + col for col in u.columns.values]
    u.reset_index(inplace=True)
    return u

# %%
additional_fields = successive_aggregates(new_transactions, 'category_1', 'purchase_amount')
additional_fields = additional_fields.merge(successive_aggregates(new_transactions, 'installments', 'purchase_amount'),
                                            on = 'card_id', how='left')
additional_fields = additional_fields.merge(successive_aggregates(new_transactions, 'city_id', 'purchase_amount'),
                                            on = 'card_id', how='left')
additional_fields = additional_fields.merge(successive_aggregates(new_transactions, 'category_1', 'installments'),
                                            on = 'card_id', how='left')

# %% [markdown]
# ### Train

# %%
train = pd.merge(train, history, on='card_id', how='left')
test = pd.merge(test, history, on='card_id', how='left')

train = pd.merge(train, authorized, on='card_id', how='left')
test = pd.merge(test, authorized, on='card_id', how='left')

train = pd.merge(train, new, on='card_id', how='left')
test = pd.merge(test, new, on='card_id', how='left')

train = pd.merge(train, final_group, on='card_id', how='left')
test = pd.merge(test, final_group, on='card_id', how='left')

train = pd.merge(train, auth_mean, on='card_id', how='left')
test = pd.merge(test, auth_mean, on='card_id', how='left')

train = pd.merge(train, additional_fields, on='card_id', how='left')
test = pd.merge(test, additional_fields, on='card_id', how='left')

# %%
features = [c for c in train.columns if c not in ['card_id', 'first_active_month']]
#features = [f for f in features if f not in unimportant_features]
categorical_feats = ['feature_2', 'feature_3']

# %%
param = {
    'num_leaves': 111,
     'min_data_in_leaf': 149, 
     'objective':'regression',
     'max_depth': 9,
     'learning_rate': 0.005,
     "boosting": "gbdt",
     "feature_fraction": 0.7522,
     "bagging_freq": 1,
     "bagging_fraction": 0.7083 ,
     "bagging_seed": 11,
     "metric": 'rmse',
     "lambda_l1": 0.2634,
     "random_state": 133,
     "verbosity": -1
}

# %%
# %%time
folds = KFold(n_splits=5, shuffle=True, random_state=15)
oof = np.zeros(len(train))
predictions = np.zeros(len(test))
start = time.time()
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train.values, target.values)):
    print("fold n°{}".format(fold_))
    trn_data = lgb.Dataset(train.iloc[trn_idx][features],
                           label=target.iloc[trn_idx],
                           categorical_feature=categorical_feats
                          )
    val_data = lgb.Dataset(train.iloc[val_idx][features],
                           label=target.iloc[val_idx],
                           categorical_feature=categorical_feats
                          )

    num_round = 10000
    clf = lgb.train(param,
                    trn_data,
                    num_round,
                    valid_sets = [trn_data, val_data],
                    verbose_eval=100,
                    early_stopping_rounds = 200)
    
    oof[val_idx] = clf.predict(train.iloc[val_idx][features], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = features
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(test[features], num_iteration=clf.best_iteration) / folds.n_splits
# Out:
# fold n°0
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.71445	valid_1's rmse: 3.77643
# [200]	training's rmse: 3.64514	valid_1's rmse: 3.72819
# [300]	training's rmse: 3.60108	valid_1's rmse: 3.7047
# [400]	training's rmse: 3.57043	valid_1's rmse: 3.69245
# [500]	training's rmse: 3.54719	valid_1's rmse: 3.68514
# [600]	training's rmse: 3.52815	valid_1's rmse: 3.68041
# [700]	training's rmse: 3.51188	valid_1's rmse: 3.67761
# [800]	training's rmse: 3.49775	valid_1's rmse: 3.67524
# [900]	training's rmse: 3.48438	valid_1's rmse: 3.67349
# [1000]	training's rmse: 3.4727	valid_1's rmse: 3.67278
# [1100]	training's rmse: 3.46046	valid_1's rmse: 3.67191
# [1200]	training's rmse: 3.4492	valid_1's rmse: 3.67147
# [1300]	training's rmse: 3.43788	valid_1's rmse: 3.67083
# [1400]	training's rmse: 3.42747	valid_1's rmse: 3.67079
# [1500]	training's rmse: 3.41738	valid_1's rmse: 3.67074
# [1600]	training's rmse: 3.40731	valid_1's rmse: 3.67069
# Early stopping, best iteration is:
# [1476]	training's rmse: 3.41966	valid_1's rmse: 3.6706
# fold n°1
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.73147	valid_1's rmse: 3.70466
# [200]	training's rmse: 3.66152	valid_1's rmse: 3.66103
# [300]	training's rmse: 3.61756	valid_1's rmse: 3.64022
# [400]	training's rmse: 3.58618	valid_1's rmse: 3.63024
# [500]	training's rmse: 3.5628	valid_1's rmse: 3.62497
# [600]	training's rmse: 3.54366	valid_1's rmse: 3.62166
# [700]	training's rmse: 3.52725	valid_1's rmse: 3.6196
# [800]	training's rmse: 3.51232	valid_1's rmse: 3.61835
# [900]	training's rmse: 3.49948	valid_1's rmse: 3.61736
# [1000]	training's rmse: 3.48705	valid_1's rmse: 3.61693
# [1100]	training's rmse: 3.47563	valid_1's rmse: 3.61658
# [1200]	training's rmse: 3.46472	valid_1's rmse: 3.61645
# [1300]	training's rmse: 3.45372	valid_1's rmse: 3.6158
# [1400]	training's rmse: 3.44233	valid_1's rmse: 3.61557
# [1500]	training's rmse: 3.43185	valid_1's rmse: 3.61585
# Early stopping, best iteration is:
# [1399]	training's rmse: 3.44245	valid_1's rmse: 3.61554
# fold n°2
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.73578	valid_1's rmse: 3.68072
# [200]	training's rmse: 3.66513	valid_1's rmse: 3.64012
# [300]	training's rmse: 3.61971	valid_1's rmse: 3.62057
# [400]	training's rmse: 3.5886	valid_1's rmse: 3.6105
# [500]	training's rmse: 3.56459	valid_1's rmse: 3.6051
# [600]	training's rmse: 3.54434	valid_1's rmse: 3.60175
# [700]	training's rmse: 3.52767	valid_1's rmse: 3.59981
# [800]	training's rmse: 3.51279	valid_1's rmse: 3.59814
# [900]	training's rmse: 3.49878	valid_1's rmse: 3.59736
# [1000]	training's rmse: 3.48658	valid_1's rmse: 3.59662
# [1100]	training's rmse: 3.47507	valid_1's rmse: 3.59613
# [1200]	training's rmse: 3.46327	valid_1's rmse: 3.59599
# [1300]	training's rmse: 3.45238	valid_1's rmse: 3.59563
# [1400]	training's rmse: 3.44152	valid_1's rmse: 3.59574
# [1500]	training's rmse: 3.43125	valid_1's rmse: 3.59568
# Early stopping, best iteration is:
# [1304]	training's rmse: 3.45193	valid_1's rmse: 3.5956
# fold n°3
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.68758	valid_1's rmse: 3.87937
# [200]	training's rmse: 3.61859	valid_1's rmse: 3.83235
# [300]	training's rmse: 3.57462	valid_1's rmse: 3.80951
# [400]	training's rmse: 3.54318	valid_1's rmse: 3.79758
# [500]	training's rmse: 3.51872	valid_1's rmse: 3.79123
# [600]	training's rmse: 3.49882	valid_1's rmse: 3.78743
# [700]	training's rmse: 3.48264	valid_1's rmse: 3.78483
# [800]	training's rmse: 3.46793	valid_1's rmse: 3.78357
# [900]	training's rmse: 3.45504	valid_1's rmse: 3.78248
# [1000]	training's rmse: 3.44248	valid_1's rmse: 3.78179
# [1100]	training's rmse: 3.43033	valid_1's rmse: 3.78143
# [1200]	training's rmse: 3.41958	valid_1's rmse: 3.78118
# [1300]	training's rmse: 3.40849	valid_1's rmse: 3.78097
# [1400]	training's rmse: 3.39769	valid_1's rmse: 3.78054
# [1500]	training's rmse: 3.38729	valid_1's rmse: 3.78067
# [1600]	training's rmse: 3.37705	valid_1's rmse: 3.78087
# Early stopping, best iteration is:
# [1425]	training's rmse: 3.39498	valid_1's rmse: 3.78044
# fold n°4
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.73198	valid_1's rmse: 3.69379
# [200]	training's rmse: 3.66104	valid_1's rmse: 3.65164
# [300]	training's rmse: 3.61662	valid_1's rmse: 3.63274
# [400]	training's rmse: 3.58524	valid_1's rmse: 3.62392
# [500]	training's rmse: 3.56166	valid_1's rmse: 3.61914
# [600]	training's rmse: 3.54284	valid_1's rmse: 3.61638
# [700]	training's rmse: 3.52684	valid_1's rmse: 3.61525
# [800]	training's rmse: 3.51236	valid_1's rmse: 3.61412
# [900]	training's rmse: 3.49952	valid_1's rmse: 3.61332
# [1000]	training's rmse: 3.48734	valid_1's rmse: 3.61306
# [1100]	training's rmse: 3.47467	valid_1's rmse: 3.6127
# [1200]	training's rmse: 3.46417	valid_1's rmse: 3.61253
# [1300]	training's rmse: 3.45267	valid_1's rmse: 3.61273
# [1400]	training's rmse: 3.44242	valid_1's rmse: 3.61287
# Early stopping, best iteration is:
# [1206]	training's rmse: 3.46345	valid_1's rmse: 3.61246
# CV score: 3.65555
# CPU times: user 48min 29s, sys: 25 s, total: 48min 54s
# Wall time: 13min 35s

# %%
cv_score = mean_squared_error(oof, target)**0.5
print("CV score: {:<8.5f}".format(cv_score))
# Out:
# CV score: 3.65555

# %% [markdown]
# ### Feature importance

# %%
cols = (feature_importance_df[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.feature.isin(cols)]

plt.figure(figsize=(14,25))
sns.barplot(x="importance",
            y="feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')

# %%
sub_df = pd.DataFrame({
    "card_id": test["card_id"].values
})

sub_df["target"] = predictions
sub_df.to_csv("output/regression_{:.6f}.csv".format(cv_score), index=False)

# %% [markdown]
# ## Feature engineering
# [Feature Engineering](https://github.com/zzsza/Play-Kaggle/blob/master/Elo-Merchant-Category-Recommendation/notebooks/04.Feature-Engineering_2nd.ipynb)

# %%
import gc
import datetime
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import lightgbm as lgb
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import StratifiedKFold

warnings.filterwarnings('ignore')
np.random.seed(402)

# %%
# %%time
df_train = pd.read_csv('input/train.csv')
df_test = pd.read_csv('input/test.csv')

df_train = reduce_mem_usage(df_train)
df_test = reduce_mem_usage(df_test)
# Out:
# Starting memory usage:  9.24 MB
# Reduced memory usage:  4.04 MB (56.2% reduction)
# Starting memory usage:  4.72 MB
# Reduced memory usage:  2.24 MB (52.5% reduction)
# CPU times: user 328 ms, sys: 125 ms, total: 453 ms
# Wall time: 657 ms

# %%
# %%time
df_hist_trans = pd.read_csv('input/historical_transactions.csv')
df_new_merchant_trans = pd.read_csv('input/new_merchant_transactions.csv')

df_hist_trans = reduce_mem_usage(df_hist_trans)
df_new_merchant_trans = reduce_mem_usage(df_new_merchant_trans)
# Out:
# Starting memory usage: 3109.54 MB
# Reduced memory usage: 1749.11 MB (43.7% reduction)
# Starting memory usage: 209.67 MB
# Reduced memory usage: 114.20 MB (45.5% reduction)
# CPU times: user 1min 12s, sys: 1min 12s, total: 2min 24s
# Wall time: 3min 25s

# %%
for df in [df_hist_trans, df_new_merchant_trans]:
    df['category_2'].fillna(1.0, inplace=True)
    df['category_3'].fillna('A', inplace=True)
    df['merchant_id'].fillna('M_ID_00a6ca8a8a', inplace=True)

# %% [markdown]
# What happens if we remove the missing data?

# %%
def get_new_columns(name,aggs):
    return [name + '_' + k + '_' + agg for k in aggs.keys() for agg in aggs[k]]

# %%
# %%time
for df in [df_hist_trans, df_new_merchant_trans]:
    df['purchase_date'] = pd.to_datetime(df['purchase_date'])
    df['year'] = df['purchase_date'].dt.year
    df['weekofyear'] = df['purchase_date'].dt.weekofyear
    df['month'] = df['purchase_date'].dt.month
    df['dayofweek'] = df['purchase_date'].dt.dayofweek
    df['weekend'] = (df.purchase_date.dt.weekday >=5).astype(int)
    df['hour'] = df['purchase_date'].dt.hour
    df['authorized_flag'] = df['authorized_flag'].map({'Y':1, 'N':0})
    df['category_1'] = df['category_1'].map({'Y':1, 'N':0}) 
    #https://www.kaggle.com/c/elo-merchant-category-recommendation/discussion/73244
    df['month_diff'] = ((datetime.datetime.today() - df['purchase_date']).dt.days)//30
    df['month_diff'] += df['month_lag']
# Out:
# CPU times: user 25.8 s, sys: 19.9 s, total: 45.7 s
# Wall time: 55.1 s

# %%
# %%time
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']
aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['authorized_flag'] = ['sum', 'mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2','category_3']:
    df_hist_trans[col+'_mean'] = df_hist_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']    

new_columns = get_new_columns('hist', aggs)
df_hist_trans_group = df_hist_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['hist_purchase_date_diff'] = (df_hist_trans_group['hist_purchase_date_max'] - df_hist_trans_group['hist_purchase_date_min']).dt.days
df_hist_trans_group['hist_purchase_date_average'] = df_hist_trans_group['hist_purchase_date_diff']/df_hist_trans_group['hist_card_id_size']
df_hist_trans_group['hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id', how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id', how='left')
del df_hist_trans_group;gc.collect()
# Out:
# CPU times: user 3min 37s, sys: 23.3 s, total: 4min
# Wall time: 4min 20s

# %% [markdown]
# Create a separate function, put params into an array

# %%
# %%time
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']
aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size']

for col in ['category_2', 'category_3']:
    df_new_merchant_trans[col+'_mean'] = df_new_merchant_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']
    
new_columns = get_new_columns('new_hist',aggs)
df_hist_trans_group = df_new_merchant_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['new_hist_purchase_date_diff'] = (df_hist_trans_group['new_hist_purchase_date_max'] - df_hist_trans_group['new_hist_purchase_date_min']).dt.days
df_hist_trans_group['new_hist_purchase_date_average'] = df_hist_trans_group['new_hist_purchase_date_diff']/df_hist_trans_group['new_hist_card_id_size']
df_hist_trans_group['new_hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['new_hist_purchase_date_max']).dt.days
df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()
# Out:
# CPU times: user 22.3 s, sys: 1.03 s, total: 23.3 s
# Wall time: 25.3 s

# %%
del df_hist_trans
gc.collect()

del df_new_merchant_trans
gc.collect()

df_train[:5]
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557          5          2          1
# 1            2017-01  C_ID_3d0044924f          4          1          0
# 2            2016-08  C_ID_d639edf6cd          2          2          0
# 3            2017-09  C_ID_186d6a6901          4          3          0
# 4            2017-11  C_ID_cdbd2c0db2          1          3          0
#
#      target  hist_month_nunique  hist_hour_nunique  hist_weekofyear_nunique  \
# 0 -0.820312                   9                 23                       35
# 1  0.392822                  12                 24                       50
# 2  0.687988                  10                 14                       22
# 3  0.142456                   6                 16                       20
# 4 -0.159790                   4                 22                       17
#
#    hist_dayofweek_nunique               ...                \
# 0                       7               ...
# 1                       7               ...
# 2                       7               ...
# 3                       7               ...
# 4                       7               ...
#
#    new_hist_weekend_sum  new_hist_weekend_mean  new_hist_category_1_sum  \
# 0                   6.0               0.260870                      0.0
# 1                   0.0               0.000000                      0.0
# 2                   1.0               1.000000                      0.0
# 3                   3.0               0.428571                      1.0
# 4                  12.0               0.333333                      2.0
#
#    new_hist_category_1_mean  new_hist_card_id_size  \
# 0                  0.000000                   23.0
# 1                  0.000000                    6.0
# 2                  0.000000                    1.0
# 3                  0.142857                    7.0
# 4                  0.055556                   36.0
#
#    new_hist_category_2_mean_mean  new_hist_category_3_mean_mean  \
# 0                      -0.550293                      -0.592773
# 1                      -0.550293                      -0.606445
# 2                      -0.548828                      -0.592773
# 3                      -0.556641                      -0.604492
# 4                      -0.555664                      -0.588379
#
#    new_hist_purchase_date_diff  new_hist_purchase_date_average  \
# 0                         54.0                        2.347826
# 1                         56.0                        9.333333
# 2                          0.0                        0.000000
# 3                         41.0                        5.857143
# 4                         57.0                        1.583333
#
#    new_hist_purchase_date_uptonow
# 0                           288.0
# 1                           318.0
# 2                           288.0
# 3                           299.0
# 4                           288.0
#
# [5 rows x 78 columns]

# %%
df_train['outliers'] = 0
df_train.loc[df_train['target'] < -30, 'outliers'] = 1
df_train['outliers'].value_counts()
# Out:
# 0    199710
# 1      2207
# Name: outliers, dtype: int64

# %%
# %%time
for df in [df_train, df_test]:
    df['first_active_month'] = pd.to_datetime(df['first_active_month'])
    df['dayofweek'] = df['first_active_month'].dt.dayofweek
    df['weekofyear'] = df['first_active_month'].dt.weekofyear
    df['month'] = df['first_active_month'].dt.month
    df['elapsed_time'] = (datetime.datetime.today() - df['first_active_month']).dt.days
    df['hist_first_buy'] = (df['hist_purchase_date_min'] - df['first_active_month']).dt.days
    df['new_hist_first_buy'] = (df['new_hist_purchase_date_min'] - df['first_active_month']).dt.days
    for f in ['hist_purchase_date_max','hist_purchase_date_min','new_hist_purchase_date_max', 'new_hist_purchase_date_min']:
        df[f] = df[f].astype(np.int64) * 1e-9
    df['card_id_total'] = df['new_hist_card_id_size']+df['hist_card_id_size']
    df['purchase_amount_total'] = df['new_hist_purchase_amount_sum']+df['hist_purchase_amount_sum']

for f in ['feature_1', 'feature_2', 'feature_3']:
    order_label = df_train.groupby([f])['outliers'].mean()
    df_train[f] = df_train[f].map(order_label)
    df_test[f] = df_test[f].map(order_label)
# Out:
# CPU times: user 328 ms, sys: 93.8 ms, total: 422 ms
# Wall time: 442 ms

# %%
df_train_columns = [c for c in df_train.columns if c not in ['card_id', 'first_active_month','target','outliers']]
target = df_train['target']
del df_train['target']

# %%
# %%time
param = {
    'num_leaves': 31,
    'min_data_in_leaf': 30, 
    'objective':'regression',
    'max_depth': -1,
    'learning_rate': 0.01,
    "min_child_samples": 20,
    "boosting": "gbdt",
    "feature_fraction": 0.9,
    "bagging_freq": 1,
    "bagging_fraction": 0.9 ,
    "bagging_seed": 11,
    "metric": 'rmse',
    "lambda_l1": 0.1, 
    "verbosity": -1,
    "nthread": -1,
    "random_state": 402
}
folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=402)
oof = np.zeros(len(df_train))
predictions = np.zeros(len(df_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train, df_train['outliers'].values)):
    print("\nFold {}.".format(fold_))
    trn_data = lgb.Dataset(df_train.iloc[trn_idx][df_train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(df_train.iloc[val_idx][df_train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 200)
    oof[val_idx] = clf.predict(df_train.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(df_test[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits
# Out:
# fold 0
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.66562	valid_1's rmse: 3.71974
# [200]	training's rmse: 3.58938	valid_1's rmse: 3.69051
# [300]	training's rmse: 3.54162	valid_1's rmse: 3.67707
# [400]	training's rmse: 3.50486	valid_1's rmse: 3.66814
# [500]	training's rmse: 3.47497	valid_1's rmse: 3.6634
# [600]	training's rmse: 3.44906	valid_1's rmse: 3.65903
# [700]	training's rmse: 3.42554	valid_1's rmse: 3.65711
# [800]	training's rmse: 3.40385	valid_1's rmse: 3.6556
# [900]	training's rmse: 3.385	valid_1's rmse: 3.65474
# [1000]	training's rmse: 3.36692	valid_1's rmse: 3.65395
# [1100]	training's rmse: 3.35004	valid_1's rmse: 3.65339
# [1200]	training's rmse: 3.33339	valid_1's rmse: 3.65267
# [1300]	training's rmse: 3.31802	valid_1's rmse: 3.65231
# [1400]	training's rmse: 3.30331	valid_1's rmse: 3.65183
# [1500]	training's rmse: 3.28882	valid_1's rmse: 3.65174
# [1600]	training's rmse: 3.27507	valid_1's rmse: 3.65168
# [1700]	training's rmse: 3.26084	valid_1's rmse: 3.65168
# Early stopping, best iteration is:
# [1574]	training's rmse: 3.27877	valid_1's rmse: 3.65153
# fold 1
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.66295	valid_1's rmse: 3.72471
# [200]	training's rmse: 3.58543	valid_1's rmse: 3.69546
# [300]	training's rmse: 3.53636	valid_1's rmse: 3.68458
# [400]	training's rmse: 3.49967	valid_1's rmse: 3.67808
# [500]	training's rmse: 3.47085	valid_1's rmse: 3.67267
# [600]	training's rmse: 3.44457	valid_1's rmse: 3.66958
# [700]	training's rmse: 3.4226	valid_1's rmse: 3.66738
# [800]	training's rmse: 3.4021	valid_1's rmse: 3.66564
# [900]	training's rmse: 3.38359	valid_1's rmse: 3.66433
# [1000]	training's rmse: 3.3666	valid_1's rmse: 3.66397
# [1100]	training's rmse: 3.35065	valid_1's rmse: 3.66373
# [1200]	training's rmse: 3.33439	valid_1's rmse: 3.66353
# [1300]	training's rmse: 3.31911	valid_1's rmse: 3.66354
# [1400]	training's rmse: 3.3046	valid_1's rmse: 3.66351
# [1500]	training's rmse: 3.29043	valid_1's rmse: 3.66321
# [1600]	training's rmse: 3.27611	valid_1's rmse: 3.6629
# [1700]	training's rmse: 3.26199	valid_1's rmse: 3.66298
# [1800]	training's rmse: 3.24778	valid_1's rmse: 3.66304
# Early stopping, best iteration is:
# [1634]	training's rmse: 3.27133	valid_1's rmse: 3.66266
# fold 2
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.66919	valid_1's rmse: 3.71606
# [200]	training's rmse: 3.59282	valid_1's rmse: 3.68521
# [300]	training's rmse: 3.54563	valid_1's rmse: 3.67194
# [400]	training's rmse: 3.50976	valid_1's rmse: 3.66417
# [500]	training's rmse: 3.48105	valid_1's rmse: 3.65979
# [600]	training's rmse: 3.45593	valid_1's rmse: 3.65712
# [700]	training's rmse: 3.43431	valid_1's rmse: 3.65534
# [800]	training's rmse: 3.41428	valid_1's rmse: 3.6543
# [900]	training's rmse: 3.39523	valid_1's rmse: 3.65351
# [1000]	training's rmse: 3.37694	valid_1's rmse: 3.65323
# [1100]	training's rmse: 3.36026	valid_1's rmse: 3.65276
# [1200]	training's rmse: 3.3447	valid_1's rmse: 3.65257
# [1300]	training's rmse: 3.32956	valid_1's rmse: 3.65256
# [1400]	training's rmse: 3.31405	valid_1's rmse: 3.65273
# Early stopping, best iteration is:
# [1244]	training's rmse: 3.33792	valid_1's rmse: 3.6523
# fold 3
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.66439	valid_1's rmse: 3.71498
# [200]	training's rmse: 3.58738	valid_1's rmse: 3.68585
# [300]	training's rmse: 3.53945	valid_1's rmse: 3.6739
# [400]	training's rmse: 3.50362	valid_1's rmse: 3.66711
# [500]	training's rmse: 3.47464	valid_1's rmse: 3.6641
# [600]	training's rmse: 3.45028	valid_1's rmse: 3.66109
# [700]	training's rmse: 3.42862	valid_1's rmse: 3.65952
# [800]	training's rmse: 3.40825	valid_1's rmse: 3.65829
# [900]	training's rmse: 3.39002	valid_1's rmse: 3.65735
# [1000]	training's rmse: 3.37199	valid_1's rmse: 3.65726
# [1100]	training's rmse: 3.35471	valid_1's rmse: 3.65731
# [1200]	training's rmse: 3.33926	valid_1's rmse: 3.65743
# Early stopping, best iteration is:
# [1060]	training's rmse: 3.36151	valid_1's rmse: 3.65706
# fold 4
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.66927	valid_1's rmse: 3.70617
# [200]	training's rmse: 3.59289	valid_1's rmse: 3.67272
# [300]	training's rmse: 3.54589	valid_1's rmse: 3.66178
# [400]	training's rmse: 3.5104	valid_1's rmse: 3.65541
# [500]	training's rmse: 3.48132	valid_1's rmse: 3.65133
# [600]	training's rmse: 3.45609	valid_1's rmse: 3.64885
# [700]	training's rmse: 3.43444	valid_1's rmse: 3.64783
# [800]	training's rmse: 3.41279	valid_1's rmse: 3.64702
# [900]	training's rmse: 3.39372	valid_1's rmse: 3.64713
# [1000]	training's rmse: 3.3755	valid_1's rmse: 3.64618
# [1100]	training's rmse: 3.35898	valid_1's rmse: 3.64605
# [1200]	training's rmse: 3.34357	valid_1's rmse: 3.64647
# Early stopping, best iteration is:
# [1077]	training's rmse: 3.36303	valid_1's rmse: 3.64596
# CPU times: user 14min 55s, sys: 2.98 s, total: 14min 58s
# Wall time: 4min

# %%
cv_score = np.sqrt(mean_squared_error(oof, target))
print("CV score: {:.6f}".format(cv_score))
# Out:
# CV score: 3.653904

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,25))
sns.barplot(x="importance", y="Feature",
            data=best_features.sort_values(by="importance", ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')

# %%
sub_df = pd.DataFrame({
    "card_id": df_test["card_id"].values
})

sub_df["target"] = predictions
sub_df.to_csv("output/regression_{:.6f}.csv".format(cv_score), index=False)

# %% [markdown]
# [Just Train Data - LGB & XGB & CatBoost w/ Blending](https://www.kaggle.com/silverstone1903/just-train-data-lgb-xgb-catboost-w-blending/data)<br/>
# [MultiModel + RIDGE + STACKING](https://www.kaggle.com/ashishpatel26/rmse-3-66-multimodel-ridge-stacking)
