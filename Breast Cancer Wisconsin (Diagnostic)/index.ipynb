# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv', sep=',')
df.drop(['Unnamed: 32'], axis=1, inplace=True)
df.rename(index=str, inplace=True, columns={"concave points_se": "concave_points_se", "concave points_mean": "concave_points_mean", "concave points_worst": "concave_points_worst"})

# %%
list(df.columns.values)
# Out:
# ['id',
#  'diagnosis',
#  'radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave_points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave_points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave_points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 569 entries, 0 to 568
# Data columns (total 32 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave_points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.corr()
# Out:
#                                id  radius_mean  texture_mean  perimeter_mean  \
# id                       1.000000     0.074626      0.099770        0.073159
# radius_mean              0.074626     1.000000      0.323782        0.997855
# texture_mean             0.099770     0.323782      1.000000        0.329533
# perimeter_mean           0.073159     0.997855      0.329533        1.000000
# area_mean                0.096893     0.987357      0.321086        0.986507
# smoothness_mean         -0.012968     0.170581     -0.023389        0.207278
# compactness_mean         0.000096     0.506124      0.236702        0.556936
# concavity_mean           0.050080     0.676764      0.302418        0.716136
# concave_points_mean      0.044158     0.822529      0.293464        0.850977
# symmetry_mean           -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.052511    -0.311631     -0.076437       -0.261477
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

f, ax = plt.subplots(figsize=(18, 18))
sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt='.2f', ax=ax)
plt.show()

# %% [markdown]
# Select the variables with high correlation

# %%
# Convert M/B to 0/1
df['diag'] = [1 if each=='M' else 0 for each in df.diagnosis]

# %%
diag = df.corr()['diag']
diag.drop(['id', 'diag'], axis=0, inplace=True)
diag.sort_values(axis=0, ascending=False, inplace=True)

# %%
diag[:10]
# Out:
# concave_points_worst    0.793566
# perimeter_worst         0.782914
# concave_points_mean     0.776614
# radius_worst            0.776454
# perimeter_mean          0.742636
# area_worst              0.733825
# radius_mean             0.730029
# area_mean               0.708984
# concavity_mean          0.696360
# concavity_worst         0.659610
# Name: diag, dtype: float64

# %% [markdown]
# ### Visualization

# %%
df.area_mean.plot(kind='line', color='g', label='area_mean', linewidth=1, alpha=0.5, grid=True, linestyle=':', figsize=(10, 10))
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend(loc='upper right')
plt.title('Line Plot')
plt.show()

# %%
plt.subplots(figsize=(10, 10))

plt.subplot(4, 1, 1)
plt.title("radius_mean-texture_mean-compactness_mean subplot")
plt.plot(df.radius_mean, color="r", label="radius_mean")
plt.legend()
plt.grid()

plt.subplot(4, 1, 2)
plt.plot(df.texture_mean, color="b", label="texture_mean")
plt.legend()
plt.grid()

plt.subplot(4, 1, 3)
plt.plot(df.compactness_mean, color="g", label="compactness_mean")
plt.legend()
plt.grid()

plt.subplot(4, 1, 4)
plt.plot(df.smoothness_mean, color="purple", label="smoothness_mean")
plt.legend()
plt.grid()

plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=1)
df.plot(kind="hist", bins=50, y='texture_mean', range=(0, 50), color='b', normed=True, grid=True, ax=axes[0])
df.plot(kind="hist", bins=50, y='texture_mean', range=(0, 50), color='b', normed=True, grid=True, ax=axes[1], cumulative=True)
#plt.savefig('graph.png')
plt.show()

# %%
def generate_mean(dep):
    a_list = list(df.diagnosis.unique())
    a_dependent = []
    for i in diagnosis_list:
        x = df[df.diagnosis == i]
        a_d = sum(x[dep])/len(x)
        a_dependent.append(a_d)

    return pd.DataFrame({
        "diagnosis": a_list,
        "output": a_dependent
    })

# %%
plt.subplots(figsize=(10, 10))
plt.title('Diagnosis vs top4 most and worst correlated variables')

plt.subplot(5, 1, 1)
output = generate_mean('concave points_worst')
sns.barplot(x=output['diagnosis'], y=output['output'])
plt.xticks(rotation= 360)
plt.ylabel('Concave points worst')

plt.subplot(5, 1, 2)
output = generate_mean('perimeter_worst')
sns.barplot(x=output['diagnosis'], y=output['output'])
plt.xticks(rotation= 360)
plt.ylabel('Perimeter worst')

plt.subplot(5, 1, 3)
output = generate_mean('concave points_mean')
sns.barplot(x=output['diagnosis'], y=output['output'])
plt.xticks(rotation= 360)
plt.ylabel('Concave points mean')

plt.subplot(5, 1, 4)
output = generate_mean('radius_worst')
sns.barplot(x=output['diagnosis'], y=output['output'])
plt.xticks(rotation= 360)
plt.xlabel('Diagnosis')
plt.ylabel('Radius worst')

plt.subplot(5, 1, 5)
output = generate_mean('smoothness_se')
sns.barplot(x=output['diagnosis'], y=output['output'])
plt.xticks(rotation= 360)
plt.xlabel('Diagnosis')
plt.ylabel('Smoothness standard error')

plt.show()

# %%
f, ax = plt.subplots(figsize = (9, 9))
sns.barplot(x=df.radius_mean, y=df.diagnosis, color='green', alpha = 0.5, label='concave points mean')
sns.barplot(x=df.perimeter_worst, y=df.diagnosis, color='lime', alpha = 0.7, label='perimeter_worst')

ax.legend(loc='lower right', frameon = True)
ax.set(xlabel='Percentage of Diagnosis', ylabel='Diagnosis', title = "Percentage of Radius Mean and Texture Mean According to Diagnosis")
